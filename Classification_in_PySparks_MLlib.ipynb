# %% [markdown]
# First things first... let's create our PySpark instance.

# %%
# import findspark
# findspark.init()

import pyspark # only run after findspark.init()
from pyspark.sql import SparkSession
# May take awhile locally
spark = SparkSession.builder.appName("ClassificationPS").getOrCreate()

cores = spark._jsc.sc().getExecutorMemoryStatus().keySet().size()
print("You are working with", cores, "core(s)")
spark
# Out:
# You are working with 1 core(s)
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-D5UD6I7:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>ClassificationPS</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Read in dependencies
from pyspark.ml.feature import VectorAssembler, StringIndexer, MinMaxScaler
from pyspark.sql.types import * 

from pyspark.ml.classification import *
from pyspark.ml.evaluation import *
from pyspark.sql.functions import *
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# %% [markdown]
# Read in our dataset

# %%
path ="Datasets/"
df = spark.read.csv(path+'beatsdataset.csv',inferSchema=True,header=True)

# %% [markdown]
# ### Check out the dataset
#
# Let's produce a print out of the dataframe so we know what we are working with.

# %%
df.limit(6).toPandas()
# Out:
#    _c0    1-ZCRm  2-Energym  3-EnergyEntropym  4-SpectralCentroidm  \
# 0    0  0.136440   0.088861          3.201201             0.262825
# 1    1  0.117039   0.108389          3.194001             0.247657
# 2    2  0.085308   0.128525          3.123837             0.217205
# 3    3  0.103050   0.167042          3.150830             0.233593
# 4    4  0.151730   0.148405          3.194498             0.293730
# 5    5  0.127047   0.153488          3.221987             0.261693
#
#    5-SpectralSpreadm  6-SpectralEntropym  7-SpectralFluxm  8-SpectralRolloffm  \
# 0           0.249212            1.114423         0.007003            0.256682
# 1           0.250288            1.065668         0.005387            0.199821
# 2           0.228652            0.789647         0.008247            0.156822
# 3           0.245032            0.967082         0.006571            0.168083
# 4           0.267231            1.353005         0.003872            0.292055
# 5           0.257361            1.090034         0.004943            0.230099
#
#    9-MFCCs1m  ...  63-ChromaVector8std  64-ChromaVector9std  \
# 0 -22.723259  ...             0.003431             0.004981
# 1 -21.775871  ...             0.004461             0.006441
# 2 -22.472722  ...             0.001529             0.004556
# 3 -21.470751  ...             0.001591             0.003514
# 4 -21.371157  ...             0.003945             0.004131
# 5 -21.234846  ...             0.002986             0.006533
#
#    65-ChromaVector10std  66-ChromaVector11std  67-ChromaVector12std  \
# 0              0.010818              0.024001              0.005201
# 1              0.007469              0.015499              0.005589
# 2              0.007723              0.017482              0.002901
# 3              0.009477              0.023162              0.004165
# 4              0.011330              0.028188              0.002639
# 5              0.010347              0.025008              0.003035
#
#    68-ChromaDeviationstd      69-BPM  70-BPMconf  71-BPMessentia    class
# 0               0.015056  133.333333    0.132792           128.0  BigRoom
# 1               0.019339  120.000000    0.112767           126.0  BigRoom
# 2               0.022201  133.333333    0.123373           129.0  BigRoom
# 3               0.015379  133.333333    0.158876           129.0  BigRoom
# 4               0.019079  133.333333    0.190708           129.0  BigRoom
# 5               0.019479  133.333333    0.168933           129.0  BigRoom
#
# [6 rows x 73 columns]

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- 1-ZCRm: double (nullable = true)
#  |-- 2-Energym: double (nullable = true)
#  |-- 3-EnergyEntropym: double (nullable = true)
#  |-- 4-SpectralCentroidm: double (nullable = true)
#  |-- 5-SpectralSpreadm: double (nullable = true)
#  |-- 6-SpectralEntropym: double (nullable = true)
#  |-- 7-SpectralFluxm: double (nullable = true)
#  |-- 8-SpectralRolloffm: double (nullable = true)
#  |-- 9-MFCCs1m: double (nullable = true)
#  |-- 10-MFCCs2m: double (nullable = true)
#  |-- 11-MFCCs3m: double (nullable = true)
#  |-- 12-MFCCs4m: double (nullable = true)
#  |-- 13-MFCCs5m: double (nullable = true)
#  |-- 14-MFCCs6m: double (nullable = true)
#  |-- 15-MFCCs7m: double (nullable = true)
#  |-- 16-MFCCs8m: double (nullable = true)
#  |-- 17-MFCCs9m: double (nullable = true)
#  |-- 18-MFCCs10m: double (nullable = true)
#  |-- 19-MFCCs11m: double (nullable = true)
#  |-- 20-MFCCs12m: double (nullable = true)
#  |-- 21-MFCCs13m: double (nullable = true)
#  |-- 22-ChromaVector1m: double (nullable = true)
#  |-- 23-ChromaVector2m: double (nullable = true)
#  |-- 24-ChromaVector3m: double (nullable = true)
#  |-- 25-ChromaVector4m: double (nullable = true)
#  |-- 26-ChromaVector5m: double (nullable = true)
#  |-- 27-ChromaVector6m: double (nullable = true)
#  |-- 28-ChromaVector7m: double (nullable = true)
#  |-- 29-ChromaVector8m: double (nullable = true)
#  |-- 30-ChromaVector9m: double (nullable = true)
#  |-- 31-ChromaVector10m: double (nullable = true)
#  |-- 32-ChromaVector11m: double (nullable = true)
#  |-- 33-ChromaVector12m: double (nullable = true)
#  |-- 34-ChromaDeviationm: double (nullable = true)
#  |-- 35-ZCRstd: double (nullable = true)
#  |-- 36-Energystd: double (nullable = true)
#  |-- 37-EnergyEntropystd: double (nullable = true)
#  |-- 38-SpectralCentroidstd: double (nullable = true)
#  |-- 39-SpectralSpreadstd: double (nullable = true)
#  |-- 40-SpectralEntropystd: double (nullable = true)
#  |-- 41-SpectralFluxstd: double (nullable = true)
#  |-- 42-SpectralRolloffstd: double (nullable = true)
#  |-- 43-MFCCs1std: double (nullable = true)
#  |-- 44-MFCCs2std: double (nullable = true)
#  |-- 45-MFCCs3std: double (nullable = true)
#  |-- 46-MFCCs4std: double (nullable = true)
#  |-- 47-MFCCs5std: double (nullable = true)
#  |-- 48-MFCCs6std: double (nullable = true)
#  |-- 49-MFCCs7std: double (nullable = true)
#  |-- 50-MFCCs8std: double (nullable = true)
#  |-- 51-MFCCs9std: double (nullable = true)
#  |-- 52-MFCCs10std: double (nullable = true)
#  |-- 53-MFCCs11std: double (nullable = true)
#  |-- 54-MFCCs12std: double (nullable = true)
#  |-- 55-MFCCs13std: double (nullable = true)
#  |-- 56-ChromaVector1std: double (nullable = true)
#  |-- 57-ChromaVector2std: double (nullable = true)
#  |-- 58-ChromaVector3std: double (nullable = true)
#  |-- 59-ChromaVector4std: double (nullable = true)
#  |-- 60-ChromaVector5std: double (nullable = true)
#  |-- 61-ChromaVector6std: double (nullable = true)
#  |-- 62-ChromaVector7std: double (nullable = true)
#  |-- 63-ChromaVector8std: double (nullable = true)
#  |-- 64-ChromaVector9std: double (nullable = true)
#  |-- 65-ChromaVector10std: double (nullable = true)
#  |-- 66-ChromaVector11std: double (nullable = true)
#  |-- 67-ChromaVector12std: double (nullable = true)
#  |-- 68-ChromaDeviationstd: double (nullable = true)
#  |-- 69-BPM: double (nullable = true)
#  |-- 70-BPMconf: double (nullable = true)
#  |-- 71-BPMessentia: double (nullable = true)
#  |-- class: string (nullable = true)

# %% [markdown]
# ### How many classes do we have and are they balanced?
#
# Just making sure :)
#
# We have a perfectly balanced dataset, however we only have 100 examples from each class which may make training a decent model challenging. But let's see what we can do!
#
# *Note: This almost never happens in real life :)*

# %%
df.groupBy("class").count().show(100)
# Out:
# +--------------------+-----+
# |               class|count|
# +--------------------+-----+
# |           PsyTrance|  100|
# |           HardDance|  100|
# |              Breaks|  100|
# |  HardcoreHardTechno|  100|
# |   IndieDanceNuDisco|  100|
# |              Trance|  100|
# |           DeepHouse|  100|
# |ElectronicaDowntempo|  100|
# |           ReggaeDub|  100|
# |             Minimal|  100|
# |         DrumAndBass|  100|
# |             Dubstep|  100|
# |             BigRoom|  100|
# |              Techno|  100|
# |               House|  100|
# |         FutureHouse|  100|
# |        ElectroHouse|  100|
# |           GlitchHop|  100|
# |           TechHouse|  100|
# |              HipHop|  100|
# |           FunkRAndB|  100|
# |               Dance|  100|
# |    ProgressiveHouse|  100|
# +--------------------+-----+

# %% [markdown]
# ## Set up our Data Formatting Function
#
# MLlib requires all input columns of your dataframe to be vectorized and our dependent variable needs to be zero indexed. We can do that using our handy dandy function we developed in the lecture.
#
# For example, with this go, I added a print statement to show the new label values for each class.

# %%
# Data Prep function
def MLClassifierDFPrep(df,input_columns,dependent_var,treat_outliers=True,treat_neg_values=True):
    
    # change label (class variable) to string type to prep for reindexing
    # Pyspark is expecting a zero indexed integer for the label column. 
    # Just incase our data is not in that format... we will treat it by using the StringIndexer built in method
    renamed = df.withColumn("label_str", df[dependent_var].cast(StringType())) #Rename and change to string type
    indexer = StringIndexer(inputCol="label_str", outputCol="label") #Pyspark is expecting the this naming convention 
    indexed = indexer.fit(renamed).transform(renamed)
    print(indexed.groupBy("class","label").count().show(100))

    # Convert all string type data in the input column list to numeric
    # Otherwise the Algorithm will not be able to process it
    numeric_inputs = []
    string_inputs = []
    for column in input_columns:
        if str(indexed.schema[column].dataType) == 'StringType':
            indexer = StringIndexer(inputCol=column, outputCol=column+"_num") 
            indexed = indexer.fit(indexed).transform(indexed)
            new_col_name = column+"_num"
            string_inputs.append(new_col_name)
        else:
            numeric_inputs.append(column)
            
    if treat_outliers == True:
        print("We are correcting for non normality now!")
        # empty dictionary d
        d = {}
        # Create a dictionary of quantiles
        for col in numeric_inputs: 
            d[col] = indexed.approxQuantile(col,[0.01,0.99],0.25) #if you want to make it go faster increase the last number
        #Now fill in the values
        for col in numeric_inputs:
            skew = indexed.agg(skewness(indexed[col])).collect() #check for skewness
            skew = skew[0][0]
            # This function will floor, cap and then log+1 (just in case there are 0 values)
            if skew > 1:
                indexed = indexed.withColumn(col, \
                log(when(df[col] < d[col][0],d[col][0])\
                .when(indexed[col] > d[col][1], d[col][1])\
                .otherwise(indexed[col] ) +1).alias(col))
                print(col+" has been treated for positive (right) skewness. (skew =)",skew,")")
            elif skew < -1:
                indexed = indexed.withColumn(col, \
                exp(when(df[col] < d[col][0],d[col][0])\
                .when(indexed[col] > d[col][1], d[col][1])\
                .otherwise(indexed[col] )).alias(col))
                print(col+" has been treated for negative (left) skewness. (skew =",skew,")")

            
    # Produce a warning if there are negative values in the dataframe that Naive Bayes cannot be used. 
    # Note: we only need to check the numeric input values since anything that is indexed won't have negative values
    minimums = df.select([min(c).alias(c) for c in df.columns if c in numeric_inputs]) # Calculate the mins for all columns in the df
    min_array = minimums.select(array(numeric_inputs).alias("mins")) # Create an array for all mins and select only the input cols
    df_minimum = min_array.select(array_min(min_array.mins)).collect() # Collect golobal min as Python object
    df_minimum = df_minimum[0][0] # Slice to get the number itself

    features_list = numeric_inputs + string_inputs
    assembler = VectorAssembler(inputCols=features_list,outputCol='features')
    output = assembler.transform(indexed).select('features','label')

#     final_data = output.select('features','label') #drop everything else
    
    # Now check for negative values and ask user if they want to correct that? 
    if df_minimum < 0:
        print(" ")
        print("WARNING: The Naive Bayes Classifier will not be able to process your dataframe as it contains negative values")
        print(" ")
    
    if treat_neg_values == True:
        print("You have opted to correct that by rescaling all your features to a range of 0 to 1")
        print(" ")
        print("We are rescaling you dataframe....")
        scaler = MinMaxScaler(inputCol="features", outputCol="scaledFeatures")

        # Compute summary statistics and generate MinMaxScalerModel
        scalerModel = scaler.fit(output)

        # rescale each feature to range [min, max].
        scaled_data = scalerModel.transform(output)
        final_data = scaled_data.select('label','scaledFeatures') # added class to the selection
        final_data = final_data.withColumnRenamed('scaledFeatures','features')
        print("Done!")

    else:
        print("You have opted not to correct that therefore you will not be able to use to Naive Bayes classifier")
        print("We will return the dataframe unscaled.")
        final_data = output
    
    return final_data

# %% [markdown]
# ## Set up our Training and Evaluation Function
#
# Let's use our handy dandy function to train and test all our classifiers we have available to us! I made two modifications here to show you just how flexible this framework is.
#
# 1. You'll see in the area where we print our coefficients and feature importances values, that I created a new output format that joins the values with their corresponding feature names so we can clearly see which value belongs to which feature. I did this by zipping the lists together and creating a Spark dataframe to allow the output to be viewed in column row format as opposed to a messy list.
# 2. The second change I added was a parameter for the folds so that I could specify the folds more easily with each iteration.

# %%
def ClassTrainEval(classifier,features,classes,folds,train,test):
    
    def FindMtype(classifier):
        # Intstantiate Model
        M = classifier
        # Learn what it is
        Mtype = type(M).__name__
        
        return Mtype
    
    Mtype = FindMtype(classifier)
    

    def IntanceFitModel(Mtype,classifier,classes,features,folds,train):
        
        if Mtype == "OneVsRest":
            # instantiate the base classifier.
            lr = LogisticRegression()
            # instantiate the One Vs Rest Classifier.
            OVRclassifier = OneVsRest(classifier=lr)
#             fitModel = OVRclassifier.fit(train)
            # Add parameters of your choice here:
            paramGrid = ParamGridBuilder() \
                .addGrid(lr.regParam, [0.1, 0.01]) \
                .build()
            #Cross Validator requires the following parameters:
            crossval = CrossValidator(estimator=OVRclassifier,
                                      estimatorParamMaps=paramGrid,
                                      evaluator=MulticlassClassificationEvaluator(),
                                      numFolds=folds) # 3 is best practice
            # Run cross-validation, and choose the best set of parameters.
            fitModel = crossval.fit(train)
            return fitModel
        if Mtype == "MultilayerPerceptronClassifier":
            # specify layers for the neural network:
            # input layer of size features, two intermediate of features+1 and same size as features
            # and output of size number of classes
            # Note: crossvalidator cannot be used here
            features_count = len(features[0][0])
            layers = [features_count, features_count+1, features_count, classes]
            MPC_classifier = MultilayerPerceptronClassifier(maxIter=100, layers=layers, blockSize=128, seed=1234)
            fitModel = MPC_classifier.fit(train)
            return fitModel
        if Mtype in("LinearSVC","GBTClassifier") and classes != 2: # These classifiers currently only accept binary classification
            print(Mtype," could not be used because PySpark currently only accepts binary classification data for this algorithm")
            return
        if Mtype in("LogisticRegression","NaiveBayes","RandomForestClassifier","GBTClassifier","LinearSVC","DecisionTreeClassifier"):
  
            # Add parameters of your choice here:
            if Mtype in("LogisticRegression"):
                paramGrid = (ParamGridBuilder() \
#                              .addGrid(classifier.regParam, [0.1, 0.01]) \
                             .addGrid(classifier.maxIter, [10, 15,20])
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("NaiveBayes"):
                paramGrid = (ParamGridBuilder() \
                             .addGrid(classifier.smoothing, [0.0, 0.2, 0.4, 0.6]) \
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("RandomForestClassifier"):
                paramGrid = (ParamGridBuilder() \
                               .addGrid(classifier.maxDepth, [2, 5, 10])
#                                .addGrid(classifier.maxBins, [5, 10, 20])
#                                .addGrid(classifier.numTrees, [5, 20, 50])
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("GBTClassifier"):
                paramGrid = (ParamGridBuilder() \
#                              .addGrid(classifier.maxDepth, [2, 5, 10, 20, 30]) \
#                              .addGrid(classifier.maxBins, [10, 20, 40, 80, 100]) \
                             .addGrid(classifier.maxIter, [10, 15,50,100])
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("LinearSVC"):
                paramGrid = (ParamGridBuilder() \
                             .addGrid(classifier.maxIter, [10, 15]) \
                             .addGrid(classifier.regParam, [0.1, 0.01]) \
                             .build())
            
            # Add parameters of your choice here:
            if Mtype in("DecisionTreeClassifier"):
                paramGrid = (ParamGridBuilder() \
#                              .addGrid(classifier.maxDepth, [2, 5, 10, 20, 30]) \
                             .addGrid(classifier.maxBins, [10, 20, 40, 80, 100]) \
                             .build())
            
            #Cross Validator requires all of the following parameters:
            crossval = CrossValidator(estimator=classifier,
                                      estimatorParamMaps=paramGrid,
                                      evaluator=MulticlassClassificationEvaluator(),
                                      numFolds=folds) # 3 + is best practice
            # Fit Model: Run cross-validation, and choose the best set of parameters.
            fitModel = crossval.fit(train)
            return fitModel
    
    fitModel = IntanceFitModel(Mtype,classifier,classes,features,folds,train)
    
    # Print feature selection metrics
    if fitModel is not None:
        
        if Mtype in("OneVsRest"):
            # Get Best Model
            BestModel = fitModel.bestModel
            global OVR_BestModel
            OVR_BestModel = BestModel
            print(" ")
            print('\033[1m' + Mtype + '\033[0m')
            # Extract list of binary models
            models = BestModel.models
            for model in models:
                print('\033[1m' + 'Intercept: '+ '\033[0m',model.intercept)
                print('\033[1m' + 'Top 20 Coefficients:'+ '\033[0m')
                coeff_array = model.coefficients.toArray()
                coeff_scores = []
                for x in coeff_array:
                    coeff_scores.append(float(x))
                # Then zip with input_columns list and create a df
                result = spark.createDataFrame(zip(input_columns,coeff_scores), schema=['feature','coeff'])
                print(result.orderBy(result["coeff"].desc()).show(truncate=False))


        if Mtype == "MultilayerPerceptronClassifier":
            print("")
            print('\033[1m' + Mtype + '\033[0m')
            print('\033[1m' + "Model Weights: "+ '\033[0m',fitModel.weights.size)
            print("")
            global MLPC_Model
            MLPC_BestModel = fitModel

        if Mtype in("DecisionTreeClassifier", "GBTClassifier","RandomForestClassifier"):
            # FEATURE IMPORTANCES
            # Estimate of the importance of each feature.
            # Each feature’s importance is the average of its importance across all trees 
            # in the ensemble The importance vector is normalized to sum to 1. 
            # Get Best Model
            BestModel = fitModel.bestModel
            print(" ")
            print('\033[1m' + Mtype," Top 20 Feature Importances"+ '\033[0m')
            print("(Scores add up to 1)")
            print("Lowest score is the least important")
            print(" ")
            featureImportances = BestModel.featureImportances.toArray()
            # Convert from numpy array to list
            imp_scores = []
            for x in featureImportances:
                imp_scores.append(float(x))
            # Then zip with input_columns list and create a df
            result = spark.createDataFrame(zip(input_columns,imp_scores), schema=['feature','score'])
            print(result.orderBy(result["score"].desc()).show(truncate=False))
            
            # Save the feature importance values and the models
            if Mtype in("DecisionTreeClassifier"):
                global DT_featureimportances
                DT_featureimportances = BestModel.featureImportances.toArray()
                global DT_BestModel
                DT_BestModel = BestModel
            if Mtype in("GBTClassifier"):
                global GBT_featureimportances
                GBT_featureimportances = BestModel.featureImportances.toArray()
                global GBT_BestModel
                GBT_BestModel = BestModel
            if Mtype in("RandomForestClassifier"):
                global RF_featureimportances
                RF_featureimportances = BestModel.featureImportances.toArray()
                global RF_BestModel
                RF_BestModel = BestModel

        # Print the coefficients
        if Mtype in("LogisticRegression"):
            # Get Best Model
            BestModel = fitModel.bestModel
            print(" ")
            print('\033[1m' + Mtype + '\033[0m')
            print("Intercept: " + str(BestModel.interceptVector))
            print('\033[1m' + " Top 20 Coefficients"+ '\033[0m')
            print("You should compares these relative to eachother")
            # Convert from numpy array to list
            coeff_array = BestModel.coefficientMatrix.toArray()
            coeff_scores = []
            for x in coeff_array[0]:
                coeff_scores.append(float(x))
            # Then zip with input_columns list and create a df
            result = spark.createDataFrame(zip(input_columns,coeff_scores), schema=['feature','coeff'])
            print(result.orderBy(result["coeff"].desc()).show(truncate=False))
            # Save the coefficient values and the models
            global LR_coefficients
            LR_coefficients = BestModel.coefficientMatrix.toArray()
            global LR_BestModel
            LR_BestModel = BestModel

        # Print the Coefficients
        if Mtype in("LinearSVC"):
            # Get Best Model
            BestModel = fitModel.bestModel
            print(" ")
            print('\033[1m' + Mtype + '\033[0m')
            print("Intercept: " + str(BestModel.intercept))
            print('\033[1m' + "Top 20 Coefficients"+ '\033[0m')
            print("You should compares these relative to eachother")
#             print("Coefficients: \n" + str(BestModel.coefficients))
            coeff_array = BestModel.coefficients.toArray()
            coeff_scores = []
            for x in coeff_array:
                coeff_scores.append(float(x))
            # Then zip with input_columns list and create a df
            result = spark.createDataFrame(zip(input_columns,coeff_scores), schema=['feature','coeff'])
            print(result.orderBy(result["coeff"].desc()).show(truncate=False))
            # Save the coefficient values and the models
            global LSVC_coefficients
            LSVC_coefficients = BestModel.coefficients.toArray()
            global LSVC_BestModel
            LSVC_BestModel = BestModel
        
   
    # Set the column names to match the external results dataframe that we will join with later:
    columns = ['Classifier', 'Result']
    
    if Mtype in("LinearSVC","GBTClassifier") and classes != 2:
        Mtype = [Mtype] # make this a list
        score = ["N/A"]
        result = spark.createDataFrame(zip(Mtype,score), schema=columns)
    else:
        predictions = fitModel.transform(test)
        MC_evaluator = MulticlassClassificationEvaluator(metricName="accuracy") # redictionCol="prediction",
        accuracy = (MC_evaluator.evaluate(predictions))*100
        Mtype = [Mtype] # make this a string
        score = [str(accuracy)] #make this a string and convert to a list
        result = spark.createDataFrame(zip(Mtype,score), schema=columns)
        result = result.withColumn('Result',result.Result.substr(0, 5))
        
    return result
    #Also returns the fit model important scores or p values

# %% [markdown]
# ## Testing Time!
#
# Now we can use these functions above to train and evaluate our models in different ways.

# %%
# Set up independ and dependent vars
input_columns = df.columns
input_columns = input_columns[1:-1] # keep only relevant columns: everything but the first and last cols
dependent_var = 'class'

# Learn how many classes there are in order to specify evaluation type based on binary or multi and turn the df into an object
class_count = df.select(countDistinct("class")).collect()
classes = class_count[0][0]

# %% [markdown]
# ### Test 1: Without outlier treatment, skew or negative value treatment
#
# This first go will act as our baseline so we can understand how our treatments affected our analysis. So I will opt out of the option for outlier treatment, skew treatment or negative value treatment which means we cannot use the naive bayes classifier.

# %%
# Call on data prep, train and evaluate functions
test1_data = MLClassifierDFPrep(df,input_columns,dependent_var,treat_outliers=False,treat_neg_values=False)
test1_data.limit(5).toPandas()

# Comment out Naive Bayes if your data still contains negative values
classifiers = [
                LogisticRegression()
                ,OneVsRest()
               ,LinearSVC()
#                ,NaiveBayes()
               ,RandomForestClassifier()
               ,GBTClassifier()
               ,DecisionTreeClassifier()
               ,MultilayerPerceptronClassifier()
              ] 

train,test = test1_data.randomSplit([0.7,0.3])
features = test1_data.select(['features']).collect()
folds = 2 # because we have limited data

#set up your results table
columns = ['Classifier', 'Result']
vals = [("Place Holder","N/A")]
results = spark.createDataFrame(vals, columns)

for classifier in classifiers:
    new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
    results = results.union(new_result)
results = results.where("Classifier!='Place Holder'")
print("!!!!!Final Results!!!!!!!!")
results.show(100,False)
# Out:
# +--------------------+-----+-----+
# |               class|label|count|
# +--------------------+-----+-----+
# |           ReggaeDub| 19.0|  100|
# |           FunkRAndB|  8.0|  100|
# |              Trance| 22.0|  100|
# |              Techno| 21.0|  100|
# |             Dubstep|  5.0|  100|
# |   IndieDanceNuDisco| 15.0|  100|
# |ElectronicaDowntempo|  7.0|  100|
# |               House| 14.0|  100|
# |  HardcoreHardTechno| 12.0|  100|
# |              HipHop| 13.0|  100|
# |           GlitchHop| 10.0|  100|
# |         DrumAndBass|  4.0|  100|
# |           PsyTrance| 18.0|  100|
# |    ProgressiveHouse| 17.0|  100|
# |        ElectroHouse|  6.0|  100|
# |           HardDance| 11.0|  100|
# |             Minimal| 16.0|  100|
# |           TechHouse| 20.0|  100|
# |           DeepHouse|  3.0|  100|
# |             BigRoom|  0.0|  100|
# |         FutureHouse|  9.0|  100|
# |               Dance|  2.0|  100|
# |              Breaks|  1.0|  100|
# +--------------------+-----+-----+
#
# None
#
# WARNING: The Naive Bayes Classifier will not be able to process your dataframe as it contains negative values
#
# You have opted not to correct that therefore you will not be able to use to Naive Bayes classifier
# We will return the dataframe unscaled.
#
# LogisticRegression
# Intercept: [0.04365812918054852,-0.09207092204138918,0.038892597831503437,0.016168633923105014,-0.024559189100313218,-0.031129789993463153,0.0440399987390589,-0.03713528345974903,0.0010524211617406925,-0.0006521791688800493,0.013210365517437714,-0.014668141993234345,-0.09024197848841617,0.11769853091935148,-0.029844354932651015,0.03453103793946187,-0.008385987498319791,0.061161480003766276,-0.0465716576721888,-0.01345266392906254,0.017981023483100517,0.008215356113103364,-0.00789742653451048]
#  Top 20 Coefficients
# You should compares these relative to eachother
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |63-ChromaVector8std |52.39447882486849 |
# |29-ChromaVector8m   |43.413006471831636|
# |33-ChromaVector12m  |15.651789239436352|
# |67-ChromaVector12std|13.21820019477059 |
# |5-SpectralSpreadm   |11.414056291298683|
# |30-ChromaVector9m   |9.201750954645707 |
# |2-Energym           |7.521563459337497 |
# |22-ChromaVector1m   |6.747299824788928 |
# |53-MFCCs11std       |6.139919744900184 |
# |54-MFCCs12std       |4.912359938687708 |
# |52-MFCCs10std       |4.837017950833956 |
# |3-EnergyEntropym    |3.9442099256954744|
# |4-SpectralCentroidm |3.449391909056495 |
# |1-ZCRm              |3.325298079207397 |
# |64-ChromaVector9std |3.219490142372435 |
# |50-MFCCs8std        |2.9303543367759737|
# |51-MFCCs9std        |2.3147940184146423|
# |24-ChromaVector3m   |1.5421474825687531|
# |31-ChromaVector10m  |1.2797493840787992|
# |8-SpectralRolloffm  |1.229991723998106 |
# +--------------------+------------------+
# only showing top 20 rows
#
# None
#
# OneVsRest
# Intercept:  -3.0444253506927375
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |63-ChromaVector8std |39.06616529595696 |
# |27-ChromaVector6m   |24.906656755015458|
# |22-ChromaVector1m   |20.197067128024596|
# |5-SpectralSpreadm   |14.805481617818705|
# |67-ChromaVector12std|14.171825600100973|
# |26-ChromaVector5m   |12.270805974614012|
# |65-ChromaVector10std|8.554329224117007 |
# |62-ChromaVector7std |7.525887757041514 |
# |53-MFCCs11std       |7.520086428362628 |
# |54-MFCCs12std       |7.121462456711331 |
# |2-Energym           |4.68398515204318  |
# |52-MFCCs10std       |4.356841180562013 |
# |58-ChromaVector3std |4.0582553591131765|
# |50-MFCCs8std        |3.34263717923282  |
# |3-EnergyEntropym    |2.32148967866214  |
# |57-ChromaVector2std |2.246710187552115 |
# |24-ChromaVector3m   |1.8258653926146746|
# |36-Energystd        |1.4252720810301058|
# |18-MFCCs10m         |1.2894330049104015|
# |15-MFCCs7m          |1.0764229596630888|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.2105960501576365
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |29-ChromaVector8m    |45.91298625381448 |
# |64-ChromaVector9std  |28.762285108726605|
# |63-ChromaVector8std  |20.827546337845934|
# |34-ChromaDeviationm  |19.67807800442814 |
# |61-ChromaVector6std  |19.034834932008394|
# |27-ChromaVector6m    |12.157525635179246|
# |65-ChromaVector10std |11.2857904474128  |
# |5-SpectralSpreadm    |11.195221454735448|
# |67-ChromaVector12std |10.067118536540058|
# |28-ChromaVector7m    |8.331691032580265 |
# |49-MFCCs7std         |5.539248927323118 |
# |42-SpectralRolloffstd|4.920483365269618 |
# |24-ChromaVector3m    |4.415475440400053 |
# |40-SpectralEntropystd|2.6039799855772094|
# |51-MFCCs9std         |2.207477275007904 |
# |48-MFCCs6std         |2.0997743318598245|
# |57-ChromaVector2std  |2.0917048727162992|
# |44-MFCCs2std         |2.0799938002887295|
# |16-MFCCs8m           |1.590383068006304 |
# |46-MFCCs4std         |1.5584995255536969|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1585955840684004
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |67-ChromaVector12std  |47.72528581544707 |
# |63-ChromaVector8std   |40.048796554436144|
# |64-ChromaVector9std   |33.66458660774655 |
# |39-SpectralSpreadstd  |17.504882760798132|
# |30-ChromaVector9m     |16.16305102274577 |
# |57-ChromaVector2std   |14.601304628914507|
# |22-ChromaVector1m     |12.65799765929018 |
# |36-Energystd          |11.321151962686544|
# |55-MFCCs13std         |10.383772419111116|
# |60-ChromaVector5std   |9.788382263999262 |
# |52-MFCCs10std         |9.244252601468515 |
# |38-SpectralCentroidstd|8.96409222405104  |
# |51-MFCCs9std          |8.604221616612078 |
# |23-ChromaVector2m     |6.822894073157471 |
# |35-ZCRstd             |6.0269291630112205|
# |26-ChromaVector5m     |5.491376972481876 |
# |27-ChromaVector6m     |4.067601797249583 |
# |50-MFCCs8std          |3.971184091350967 |
# |62-ChromaVector7std   |3.0765485228094067|
# |31-ChromaVector10m    |2.5891936986707846|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.142317678952957
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |154.9100202461055 |
# |67-ChromaVector12std  |76.19326955279564 |
# |63-ChromaVector8std   |73.73108440672856 |
# |33-ChromaVector12m    |47.12280175404157 |
# |64-ChromaVector9std   |34.92740480497519 |
# |27-ChromaVector6m     |32.98719604286999 |
# |22-ChromaVector1m     |28.3536641548175  |
# |57-ChromaVector2std   |24.323971639197925|
# |23-ChromaVector2m     |22.627923948355374|
# |36-Energystd          |17.341821904389203|
# |26-ChromaVector5m     |15.472655135909958|
# |38-SpectralCentroidstd|14.909502587862523|
# |30-ChromaVector9m     |14.070381233749432|
# |58-ChromaVector3std   |10.335851199173153|
# |41-SpectralFluxstd    |7.35237035027575  |
# |55-MFCCs13std         |7.3230578840393115|
# |70-BPMconf            |6.905584533607187 |
# |34-ChromaDeviationm   |6.881882114546318 |
# |32-ChromaVector11m    |6.531459717933243 |
# |53-MFCCs11std         |4.541928407586315 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.097969936894313
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |59-ChromaVector4std  |44.23385230933588 |
# |5-SpectralSpreadm    |26.090495884045012|
# |23-ChromaVector2m    |19.018799381391066|
# |2-Energym            |12.950119974579984|
# |26-ChromaVector5m    |11.625553094081829|
# |66-ChromaVector11std |11.57511807112908 |
# |63-ChromaVector8std  |11.169001243161347|
# |61-ChromaVector6std  |9.06098797264503  |
# |22-ChromaVector1m    |7.018143586511155 |
# |4-SpectralCentroidm  |7.013188028683608 |
# |42-SpectralRolloffstd|5.511502108760981 |
# |7-SpectralFluxm      |5.422415218135732 |
# |60-ChromaVector5std  |4.908682203392094 |
# |24-ChromaVector3m    |3.383849492689965 |
# |48-MFCCs6std         |2.86104041097386  |
# |20-MFCCs12m          |2.3380967236215597|
# |17-MFCCs9m           |1.6588003533420144|
# |40-SpectralEntropystd|1.5649286942108   |
# |47-MFCCs5std         |1.5192017922141619|
# |43-MFCCs1std         |0.8886336894804641|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.175981033160976
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |29-ChromaVector8m    |61.50310912016007 |
# |27-ChromaVector6m    |41.2464901722174  |
# |68-ChromaDeviationstd|39.052450301536275|
# |34-ChromaDeviationm  |35.25370944575225 |
# |33-ChromaVector12m   |26.248578154919144|
# |65-ChromaVector10std |18.479261205750813|
# |59-ChromaVector4std  |17.076919533367327|
# |24-ChromaVector3m    |7.380242277713601 |
# |35-ZCRstd            |6.815791296112196 |
# |26-ChromaVector5m    |6.182765171357836 |
# |2-Energym            |5.065792704961966 |
# |36-Energystd         |4.612294811581362 |
# |47-MFCCs5std         |4.109937990405856 |
# |8-SpectralRolloffm   |3.9320986158161797|
# |53-MFCCs11std        |3.6604280464353574|
# |4-SpectralCentroidm  |3.6394587788483324|
# |58-ChromaVector3std  |3.4945783494845024|
# |61-ChromaVector6std  |3.384643919080134 |
# |45-MFCCs3std         |3.0123422592967963|
# |20-MFCCs12m          |2.1778996297186817|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.043978118947482
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |22-ChromaVector1m    |64.3716602975251  |
# |57-ChromaVector2std  |42.904816468264876|
# |31-ChromaVector10m   |33.15756564089285 |
# |30-ChromaVector9m    |26.01460431493487 |
# |41-SpectralFluxstd   |14.761189211044204|
# |68-ChromaDeviationstd|8.734359446933471 |
# |2-Energym            |8.258561845586746 |
# |25-ChromaVector4m    |7.480639573077569 |
# |51-MFCCs9std         |5.4760388834927864|
# |27-ChromaVector6m    |5.403446433164335 |
# |5-SpectralSpreadm    |5.000548793866543 |
# |58-ChromaVector3std  |3.6969254290496645|
# |36-Energystd         |3.531439041570674 |
# |3-EnergyEntropym     |2.7616812311722496|
# |62-ChromaVector7std  |2.4730911386265846|
# |50-MFCCs8std         |2.4374817272201033|
# |46-MFCCs4std         |2.1904423514820586|
# |19-MFCCs11m          |2.0494613976147784|
# |16-MFCCs8m           |1.7333856359696982|
# |18-MFCCs10m          |0.9132791469691033|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.126452833286426
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |33-ChromaVector12m   |76.88318379439964 |
# |23-ChromaVector2m    |70.38971141748898 |
# |30-ChromaVector9m    |48.51378280030019 |
# |68-ChromaDeviationstd|28.229417761095153|
# |26-ChromaVector5m    |21.014985575435116|
# |61-ChromaVector6std  |18.861543473006368|
# |32-ChromaVector11m   |13.410932799960312|
# |27-ChromaVector6m    |11.670569638552962|
# |62-ChromaVector7std  |9.9759680846249   |
# |25-ChromaVector4m    |8.92532959616784  |
# |39-SpectralSpreadstd |6.489831546737301 |
# |48-MFCCs6std         |5.829698035854441 |
# |54-MFCCs12std        |4.06768872337585  |
# |36-Energystd         |3.0671478230621902|
# |37-EnergyEntropystd  |2.392318192278436 |
# |55-MFCCs13std        |1.7203256016523218|
# |34-ChromaDeviationm  |1.237146619701996 |
# |16-MFCCs8m           |1.0204204443885567|
# |50-MFCCs8std         |0.908769042538805 |
# |53-MFCCs11std        |0.6923309698645624|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.071764231262372
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |64-ChromaVector9std  |97.61807507214226 |
# |63-ChromaVector8std  |76.09024568329939 |
# |68-ChromaDeviationstd|43.75699019609616 |
# |22-ChromaVector1m    |38.65967015944032 |
# |57-ChromaVector2std  |35.783228286639   |
# |65-ChromaVector10std |27.610470537074136|
# |67-ChromaVector12std |23.4519562382018  |
# |26-ChromaVector5m    |19.454125367750407|
# |60-ChromaVector5std  |18.593700825923793|
# |62-ChromaVector7std  |16.51743226663262 |
# |31-ChromaVector10m   |13.104081139620746|
# |39-SpectralSpreadstd |12.564322594197803|
# |55-MFCCs13std        |8.079266628970142 |
# |36-Energystd         |7.926349871132988 |
# |32-ChromaVector11m   |6.396122669031395 |
# |51-MFCCs9std         |6.0400956818518665|
# |48-MFCCs6std         |5.391090127120632 |
# |5-SpectralSpreadm    |5.199899256664621 |
# |50-MFCCs8std         |4.899461358787705 |
# |49-MFCCs7std         |3.719393590100465 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1095645949347412
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |57-ChromaVector2std   |35.28331218137694 |
# |61-ChromaVector6std   |30.723135573205305|
# |64-ChromaVector9std   |27.846976145878166|
# |60-ChromaVector5std   |19.13572658948042 |
# |30-ChromaVector9m     |16.309860706588825|
# |38-SpectralCentroidstd|15.493831879852571|
# |67-ChromaVector12std  |13.974323412994039|
# |23-ChromaVector2m     |11.504477436872161|
# |62-ChromaVector7std   |11.341065234110385|
# |36-Energystd          |10.658057350640677|
# |41-SpectralFluxstd    |9.732052244604576 |
# |63-ChromaVector8std   |8.38845843781071  |
# |55-MFCCs13std         |7.7177706708705   |
# |3-EnergyEntropym      |5.9246448804253395|
# |59-ChromaVector4std   |5.760177466860955 |
# |39-SpectralSpreadstd  |5.1758170712599645|
# |58-ChromaVector3std   |4.638557728364303 |
# |42-SpectralRolloffstd |4.360173059601559 |
# |2-Energym             |2.6964036546927326|
# |54-MFCCs12std         |2.3579542099441384|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0662601542031624
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |56-ChromaVector1std   |117.85613337445157|
# |26-ChromaVector5m     |22.905328427390614|
# |59-ChromaVector4std   |19.112961436190776|
# |41-SpectralFluxstd    |18.861195545305485|
# |66-ChromaVector11std  |13.581545584209746|
# |27-ChromaVector6m     |13.210599720851647|
# |35-ZCRstd             |9.814277955007325 |
# |38-SpectralCentroidstd|8.474581836597421 |
# |39-SpectralSpreadstd  |8.420312351220224 |
# |58-ChromaVector3std   |8.306086018127688 |
# |62-ChromaVector7std   |7.999104948827614 |
# |32-ChromaVector11m    |7.439392578706225 |
# |52-MFCCs10std         |7.431112433817522 |
# |23-ChromaVector2m     |6.799290815087861 |
# |50-MFCCs8std          |6.728907407416623 |
# |65-ChromaVector10std  |5.574781819275399 |
# |53-MFCCs11std         |5.307090321431006 |
# |48-MFCCs6std          |3.853200852397195 |
# |25-ChromaVector4m     |3.4216009603906206|
# |49-MFCCs7std          |2.645474991079714 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.174046171288228
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |63-ChromaVector8std  |66.40247275248103 |
# |67-ChromaVector12std |61.474172038041516|
# |68-ChromaDeviationstd|49.11360426728768 |
# |25-ChromaVector4m    |22.39593938306099 |
# |61-ChromaVector6std  |20.19126867428992 |
# |59-ChromaVector4std  |18.45509586992    |
# |70-BPMconf           |17.424684527223103|
# |2-Energym            |6.841519874708068 |
# |52-MFCCs10std        |5.068478378975778 |
# |28-ChromaVector7m    |4.325081064994499 |
# |48-MFCCs6std         |3.5713605482355444|
# |49-MFCCs7std         |2.856932280660194 |
# |46-MFCCs4std         |2.5144814861569293|
# |35-ZCRstd            |2.214574840420448 |
# |13-MFCCs5m           |2.189105648375514 |
# |58-ChromaVector3std  |2.1259570360778755|
# |1-ZCRm               |1.9152473916377142|
# |5-SpectralSpreadm    |1.7686045253847273|
# |51-MFCCs9std         |1.0454815367323536|
# |18-MFCCs10m          |1.032987541776014 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.034038038598532
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |30-ChromaVector9m     |62.43152906802994 |
# |7-SpectralFluxm       |46.28569862223039 |
# |33-ChromaVector12m    |14.597828305438707|
# |2-Energym             |13.883201692461304|
# |61-ChromaVector6std   |10.514538943809697|
# |70-BPMconf            |10.25240536021422 |
# |38-SpectralCentroidstd|10.090549337157636|
# |1-ZCRm                |8.297180038293565 |
# |28-ChromaVector7m     |6.1134979104269505|
# |62-ChromaVector7std   |2.678883519813279 |
# |21-MFCCs13m           |2.5022549457320467|
# |13-MFCCs5m            |2.4833628898283533|
# |35-ZCRstd             |2.3703611991916955|
# |45-MFCCs3std          |2.0781712448393614|
# |24-ChromaVector3m     |1.308828035759676 |
# |37-EnergyEntropystd   |1.2187891993550606|
# |15-MFCCs7m            |0.6555839400541934|
# |4-SpectralCentroidm   |0.6326040132442511|
# |49-MFCCs7std          |0.5642181783649655|
# |3-EnergyEntropym      |0.4869601407527931|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0170477555638553
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |63-ChromaVector8std   |72.03009827052037 |
# |27-ChromaVector6m     |56.40435309778157 |
# |55-MFCCs13std         |18.26016527128694 |
# |36-Energystd          |17.888317781135544|
# |34-ChromaDeviationm   |12.628155160762404|
# |60-ChromaVector5std   |12.39063382188308 |
# |30-ChromaVector9m     |11.432959682706288|
# |54-MFCCs12std         |9.781333024094966 |
# |31-ChromaVector10m    |7.3283936351240735|
# |52-MFCCs10std         |5.702926901481811 |
# |66-ChromaVector11std  |3.789798539316535 |
# |44-MFCCs2std          |3.409042917474769 |
# |46-MFCCs4std          |2.6338176267597126|
# |24-ChromaVector3m     |2.5749973321484476|
# |18-MFCCs10m           |2.5666959408726453|
# |38-SpectralCentroidstd|2.2070753215180874|
# |48-MFCCs6std          |2.177607589770138 |
# |49-MFCCs7std          |1.984214961774203 |
# |2-Energym             |1.472523929602799 |
# |53-MFCCs11std         |1.0863049791780943|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.130112000449331
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |57-ChromaVector2std   |115.06387149019196|
# |64-ChromaVector9std   |56.83000251184523 |
# |63-ChromaVector8std   |41.69945157424205 |
# |25-ChromaVector4m     |33.696938323525856|
# |38-SpectralCentroidstd|17.30903528957374 |
# |35-ZCRstd             |15.47553184250307 |
# |59-ChromaVector4std   |11.990731288373807|
# |27-ChromaVector6m     |11.035844791889389|
# |58-ChromaVector3std   |8.965768384540924 |
# |66-ChromaVector11std  |5.928594603883297 |
# |36-Energystd          |5.706195520459838 |
# |52-MFCCs10std         |5.556152401220702 |
# |54-MFCCs12std         |5.20133864523316  |
# |26-ChromaVector5m     |4.729650966117907 |
# |1-ZCRm                |4.288929538766295 |
# |46-MFCCs4std          |3.938028621977229 |
# |60-ChromaVector5std   |3.3309564813593218|
# |42-SpectralRolloffstd |1.2541397585883012|
# |40-SpectralEntropystd |1.0611832780100634|
# |3-EnergyEntropym      |1.0090658283330498|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0395059388752634
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |68-ChromaDeviationstd|60.410053704810196|
# |64-ChromaVector9std  |34.96840190861717 |
# |39-SpectralSpreadstd |33.75554210192536 |
# |60-ChromaVector5std  |32.42399144576028 |
# |23-ChromaVector2m    |21.351344132912672|
# |36-Energystd         |17.126716986184235|
# |25-ChromaVector4m    |16.17225994474989 |
# |63-ChromaVector8std  |14.94814352212668 |
# |56-ChromaVector1std  |13.921700852082878|
# |5-SpectralSpreadm    |11.715415059664613|
# |61-ChromaVector6std  |11.501450536506269|
# |31-ChromaVector10m   |10.863898165185109|
# |65-ChromaVector10std |10.333180347684737|
# |22-ChromaVector1m    |10.010626407625509|
# |32-ChromaVector11m   |9.083771592616928 |
# |58-ChromaVector3std  |7.322495157676614 |
# |54-MFCCs12std        |6.998008292904012 |
# |49-MFCCs7std         |6.519911247055753 |
# |29-ChromaVector8m    |5.762032684760138 |
# |66-ChromaVector11std |5.4344733181856215|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.223661411067212
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |7-SpectralFluxm       |63.97312025565289 |
# |41-SpectralFluxstd    |52.53012253563141 |
# |33-ChromaVector12m    |44.18712906132311 |
# |39-SpectralSpreadstd  |34.89056934249343 |
# |29-ChromaVector8m     |31.2886202457289  |
# |64-ChromaVector9std   |28.42186999317007 |
# |30-ChromaVector9m     |23.169043807547922|
# |27-ChromaVector6m     |17.581849612270098|
# |38-SpectralCentroidstd|16.186571372632354|
# |25-ChromaVector4m     |15.74561203724476 |
# |59-ChromaVector4std   |8.636166422299691 |
# |34-ChromaDeviationm   |6.292245532967944 |
# |31-ChromaVector10m    |5.780449764610481 |
# |32-ChromaVector11m    |5.328374724566549 |
# |28-ChromaVector7m     |5.1669533462031465|
# |47-MFCCs5std          |4.946877757778005 |
# |21-MFCCs13m           |3.3482233477958596|
# |58-ChromaVector3std   |3.322718278705576 |
# |37-EnergyEntropystd   |1.975849827600431 |
# |45-MFCCs3std          |1.9167590210463348|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0210224604345033
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |30-ChromaVector9m     |53.55613828254077 |
# |29-ChromaVector8m     |33.92684861337867 |
# |63-ChromaVector8std   |32.81537239916795 |
# |64-ChromaVector9std   |30.388106909417875|
# |61-ChromaVector6std   |27.926116019007925|
# |27-ChromaVector6m     |22.969948081900622|
# |26-ChromaVector5m     |22.89605741474594 |
# |39-SpectralSpreadstd  |20.63873081123105 |
# |41-SpectralFluxstd    |17.57805739793357 |
# |36-Energystd          |15.709619260980313|
# |38-SpectralCentroidstd|14.986056032504885|
# |22-ChromaVector1m     |14.786139494999071|
# |65-ChromaVector10std  |12.383410962489242|
# |31-ChromaVector10m    |11.044006867004411|
# |32-ChromaVector11m    |8.986311219908846 |
# |58-ChromaVector3std   |7.089567317669448 |
# |7-SpectralFluxm       |6.585259865734377 |
# |70-BPMconf            |5.418987073842146 |
# |51-MFCCs9std          |4.530158992140915 |
# |55-MFCCs13std         |3.685449509134573 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.8623966158338887
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |29-ChromaVector8m    |148.9134687469653 |
# |67-ChromaVector12std |75.58768470692694 |
# |7-SpectralFluxm      |72.2772228907019  |
# |68-ChromaDeviationstd|49.07356524794764 |
# |57-ChromaVector2std  |40.65099654310716 |
# |41-SpectralFluxstd   |38.98104169483094 |
# |63-ChromaVector8std  |32.77955967478523 |
# |33-ChromaVector12m   |28.387248348447173|
# |31-ChromaVector10m   |23.15368729866397 |
# |62-ChromaVector7std  |22.42313320582171 |
# |27-ChromaVector6m    |21.682384645931595|
# |66-ChromaVector11std |16.84042963621882 |
# |26-ChromaVector5m    |12.614767324682443|
# |49-MFCCs7std         |4.341333847048534 |
# |36-Energystd         |4.058564857117091 |
# |32-ChromaVector11m   |2.8838299596114925|
# |39-SpectralSpreadstd |2.3465727980693534|
# |64-ChromaVector9std  |1.495311381886844 |
# |3-EnergyEntropym     |1.3976472345370128|
# |23-ChromaVector2m    |1.2176390614069914|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.102940008677713
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |63-ChromaVector8std  |66.68831836761255 |
# |39-SpectralSpreadstd |55.50911324612386 |
# |27-ChromaVector6m    |43.85446915138947 |
# |68-ChromaDeviationstd|36.19082269137281 |
# |66-ChromaVector11std |35.83399964214412 |
# |67-ChromaVector12std |32.835413495945495|
# |25-ChromaVector4m    |24.618347177727138|
# |59-ChromaVector4std  |22.92971313336801 |
# |55-MFCCs13std        |10.285599366900067|
# |54-MFCCs12std        |9.437264757081278 |
# |47-MFCCs5std         |8.542558480902258 |
# |35-ZCRstd            |7.1316577160407855|
# |62-ChromaVector7std  |6.629590378398341 |
# |56-ChromaVector1std  |5.457118652060079 |
# |32-ChromaVector11m   |4.785971941804556 |
# |53-MFCCs11std        |4.414781952386972 |
# |34-ChromaDeviationm  |3.9111644066587457|
# |65-ChromaVector10std |3.8650527319504504|
# |50-MFCCs8std         |3.847910505594244 |
# |45-MFCCs3std         |3.369302260202888 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0824992293438918
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |67-ChromaVector12std  |63.650430315278136|
# |25-ChromaVector4m     |37.791412143667905|
# |56-ChromaVector1std   |30.113110127987735|
# |65-ChromaVector10std  |25.027305197168296|
# |41-SpectralFluxstd    |21.766749612419815|
# |38-SpectralCentroidstd|17.76445692977428 |
# |35-ZCRstd             |15.312079618119768|
# |60-ChromaVector5std   |15.126225365087839|
# |7-SpectralFluxm       |12.98712599684645 |
# |30-ChromaVector9m     |8.238896839587035 |
# |31-ChromaVector10m    |4.973368886018223 |
# |28-ChromaVector7m     |4.520631689290267 |
# |29-ChromaVector8m     |4.058141670157543 |
# |36-Energystd          |3.823425774178499 |
# |34-ChromaDeviationm   |3.462477099601752 |
# |54-MFCCs12std         |3.232964479343744 |
# |20-MFCCs12m           |2.7057082337880867|
# |42-SpectralRolloffstd |2.5866553856048853|
# |47-MFCCs5std          |2.5041638148627743|
# |70-BPMconf            |1.8410225909768614|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0771612431324384
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |65-ChromaVector10std  |63.17710015993856 |
# |29-ChromaVector8m     |52.84463447975046 |
# |22-ChromaVector1m     |44.55772838854743 |
# |41-SpectralFluxstd    |30.78518831350166 |
# |25-ChromaVector4m     |21.457117812928516|
# |23-ChromaVector2m     |18.810158999013687|
# |56-ChromaVector1std   |15.422689527466185|
# |38-SpectralCentroidstd|12.69705969980787 |
# |60-ChromaVector5std   |10.129314287375447|
# |59-ChromaVector4std   |9.573811979634515 |
# |34-ChromaDeviationm   |7.901883742554793 |
# |66-ChromaVector11std  |7.376542782862858 |
# |55-MFCCs13std         |6.665163684874904 |
# |7-SpectralFluxm       |5.988895897516293 |
# |33-ChromaVector12m    |5.747994658183974 |
# |36-Energystd          |4.4558580747556755|
# |42-SpectralRolloffstd |4.401931521359639 |
# |53-MFCCs11std         |4.182877845816515 |
# |28-ChromaVector7m     |3.906476346767476 |
# |30-ChromaVector9m     |3.2464010499632354|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.103470285907061
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |33-ChromaVector12m   |49.029024463586005|
# |30-ChromaVector9m    |42.840746278909855|
# |56-ChromaVector1std  |38.496474588496056|
# |25-ChromaVector4m    |35.69363063531303 |
# |23-ChromaVector2m    |27.583963048071848|
# |59-ChromaVector4std  |25.92332821710247 |
# |60-ChromaVector5std  |23.85468363571677 |
# |66-ChromaVector11std |22.48991668926295 |
# |31-ChromaVector10m   |22.08158713269235 |
# |41-SpectralFluxstd   |20.10683952682771 |
# |7-SpectralFluxm      |16.231719374369867|
# |5-SpectralSpreadm    |12.991017100730524|
# |68-ChromaDeviationstd|10.95715197778842 |
# |62-ChromaVector7std  |9.852108428520951 |
# |27-ChromaVector6m    |8.29979108190473  |
# |22-ChromaVector1m    |5.30935576882339  |
# |19-MFCCs11m          |3.881735406304735 |
# |4-SpectralCentroidm  |3.720937880465095 |
# |3-EnergyEntropym     |3.6183372478145506|
# |1-ZCRm               |3.3568506539230754|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# LinearSVC  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# RandomForestClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +----------------------+--------------------+
# |feature               |score               |
# +----------------------+--------------------+
# |71-BPMessentia        |0.08595941236706611 |
# |69-BPM                |0.05346420899866395 |
# |1-ZCRm                |0.025104930122896347|
# |70-BPMconf            |0.023055259448645393|
# |2-Energym             |0.022948002560905352|
# |39-SpectralSpreadstd  |0.0223882589372081  |
# |52-MFCCs10std         |0.022058997471914876|
# |3-EnergyEntropym      |0.020905540694354546|
# |43-MFCCs1std          |0.02088487907578913 |
# |10-MFCCs2m            |0.018536355627356515|
# |54-MFCCs12std         |0.018420324722216913|
# |44-MFCCs2std          |0.018007113447414548|
# |7-SpectralFluxm       |0.017648215784262414|
# |9-MFCCs1m             |0.017039412094496966|
# |48-MFCCs6std          |0.01693427224905206 |
# |38-SpectralCentroidstd|0.01669301770223185 |
# |37-EnergyEntropystd   |0.015502949278675095|
# |55-MFCCs13std         |0.015131934540155014|
# |45-MFCCs3std          |0.015028876034960758|
# |47-MFCCs5std          |0.014654445611549754|
# +----------------------+--------------------+
# only showing top 20 rows
#
# None
# GBTClassifier  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# DecisionTreeClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +---------------------+--------------------+
# |feature              |score               |
# +---------------------+--------------------+
# |71-BPMessentia       |0.23667465941470622 |
# |69-BPM               |0.19234135392531637 |
# |39-SpectralSpreadstd |0.1494717031195645  |
# |70-BPMconf           |0.0811765720678635  |
# |52-MFCCs10std        |0.05899952815168946 |
# |6-SpectralEntropym   |0.03609252404059952 |
# |9-MFCCs1m            |0.03455736938634123 |
# |40-SpectralEntropystd|0.02537053389979739 |
# |7-SpectralFluxm      |0.02531739699365711 |
# |50-MFCCs8std         |0.024369914429961406|
# |2-Energym            |0.020013130614446588|
# |65-ChromaVector10std |0.016988137982291936|
# |47-MFCCs5std         |0.014777782624491668|
# |37-EnergyEntropystd  |0.013453497174257992|
# |58-ChromaVector3std  |0.011798896279785816|
# |56-ChromaVector1std  |0.011680656505345203|
# |24-ChromaVector3m    |0.011471142573153513|
# |11-MFCCs3m           |0.011087461354267036|
# |28-ChromaVector7m    |0.007357738691327105|
# |3-EnergyEntropym     |0.00618862963285963 |
# +---------------------+--------------------+
# only showing top 20 rows
#
# None
#
# MultilayerPerceptronClassifier
# Model Weights:  12023
#
# !!!!!Final Results!!!!!!!!
# +------------------------------+------+
# |Classifier                    |Result|
# +------------------------------+------+
# |LogisticRegression            |41.20 |
# |OneVsRest                     |45.53 |
# |LinearSVC                     |N/A   |
# |RandomForestClassifier        |45.94 |
# |GBTClassifier                 |N/A   |
# |DecisionTreeClassifier        |33.24 |
# |MultilayerPerceptronClassifier|14.10 |
# +------------------------------+------+

# %% [markdown]
# ### Test 2: Test treatments
#
# Train and evaluate models on treated data (outliers, skewness and negative values) and compare to baseline (#1).

# %%
# Call on data prep, train and evaluate functions
test2_data = MLClassifierDFPrep(df,input_columns,dependent_var,treat_outliers=True,treat_neg_values=True)
test2_data.limit(5).toPandas()

# Comment out Naive Bayes if your data still contains negative values
classifiers = [
                LogisticRegression()
                ,OneVsRest()
               ,LinearSVC()
               ,NaiveBayes()
               ,RandomForestClassifier()
               ,GBTClassifier()
               ,DecisionTreeClassifier()
               ,MultilayerPerceptronClassifier()
              ] 

train,test = test2_data.randomSplit([0.7,0.3])
features = test2_data.select(['features']).collect()
folds = 2

#set up your results table
columns = ['Classifier', 'Result']
vals = [("Place Holder","N/A")]
results = spark.createDataFrame(vals, columns)

for classifier in classifiers:
    new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
    results = results.union(new_result)
results = results.where("Classifier!='Place Holder'")
print("!!!!!Final Results!!!!!!!!")
results.show(100,False)
# Out:
# +--------------------+-----+-----+
# |               class|label|count|
# +--------------------+-----+-----+
# |           ReggaeDub| 19.0|  100|
# |           FunkRAndB|  8.0|  100|
# |              Trance| 22.0|  100|
# |              Techno| 21.0|  100|
# |             Dubstep|  5.0|  100|
# |   IndieDanceNuDisco| 15.0|  100|
# |ElectronicaDowntempo|  7.0|  100|
# |               House| 14.0|  100|
# |  HardcoreHardTechno| 12.0|  100|
# |              HipHop| 13.0|  100|
# |           GlitchHop| 10.0|  100|
# |         DrumAndBass|  4.0|  100|
# |           PsyTrance| 18.0|  100|
# |    ProgressiveHouse| 17.0|  100|
# |        ElectroHouse|  6.0|  100|
# |           HardDance| 11.0|  100|
# |             Minimal| 16.0|  100|
# |           TechHouse| 20.0|  100|
# |           DeepHouse|  3.0|  100|
# |             BigRoom|  0.0|  100|
# |         FutureHouse|  9.0|  100|
# |               Dance|  2.0|  100|
# |              Breaks|  1.0|  100|
# +--------------------+-----+-----+
#
# None
# We are correcting for non normality now!
# 7-SpectralFluxm has been treated for positive (right) skewness. (skew =) 1.6396138160129063 )
# 22-ChromaVector1m has been treated for positive (right) skewness. (skew =) 2.4162415204309258 )
# 23-ChromaVector2m has been treated for positive (right) skewness. (skew =) 4.154796693680583 )
# 24-ChromaVector3m has been treated for positive (right) skewness. (skew =) 1.1974019617504328 )
# 25-ChromaVector4m has been treated for positive (right) skewness. (skew =) 2.446635863594906 )
# 26-ChromaVector5m has been treated for positive (right) skewness. (skew =) 2.154482876187508 )
# 27-ChromaVector6m has been treated for positive (right) skewness. (skew =) 2.01234064472543 )
# 28-ChromaVector7m has been treated for positive (right) skewness. (skew =) 1.1829228989215521 )
# 29-ChromaVector8m has been treated for positive (right) skewness. (skew =) 3.7372643733999955 )
# 30-ChromaVector9m has been treated for positive (right) skewness. (skew =) 2.4117416421548645 )
# 31-ChromaVector10m has been treated for positive (right) skewness. (skew =) 2.1979538518563233 )
# 32-ChromaVector11m has been treated for positive (right) skewness. (skew =) 2.1924295373960554 )
# 33-ChromaVector12m has been treated for positive (right) skewness. (skew =) 2.278981912155668 )
# 41-SpectralFluxstd has been treated for positive (right) skewness. (skew =) 1.8577721462401056 )
# 56-ChromaVector1std has been treated for positive (right) skewness. (skew =) 1.9111935514138085 )
# 57-ChromaVector2std has been treated for positive (right) skewness. (skew =) 2.9078740765487394 )
# 59-ChromaVector4std has been treated for positive (right) skewness. (skew =) 2.9677243313898827 )
# 60-ChromaVector5std has been treated for positive (right) skewness. (skew =) 2.3681450229993315 )
# 61-ChromaVector6std has been treated for positive (right) skewness. (skew =) 2.3950817653605396 )
# 63-ChromaVector8std has been treated for positive (right) skewness. (skew =) 2.801578595136121 )
# 64-ChromaVector9std has been treated for positive (right) skewness. (skew =) 1.7779798465610313 )
# 65-ChromaVector10std has been treated for positive (right) skewness. (skew =) 1.9944501757850421 )
# 66-ChromaVector11std has been treated for positive (right) skewness. (skew =) 1.1835182964170816 )
# 67-ChromaVector12std has been treated for positive (right) skewness. (skew =) 2.087086908618814 )
# 69-BPM has been treated for positive (right) skewness. (skew =) 2.9547734198613234 )
# 70-BPMconf has been treated for positive (right) skewness. (skew =) 1.0889332324135428 )
#
# WARNING: The Naive Bayes Classifier will not be able to process your dataframe as it contains negative values
#
# You have opted to correct that by rescaling all your features to a range of 0 to 1
#
# We are rescaling you dataframe....
# Done!
#
# LogisticRegression
# Intercept: [-0.05148889179750521,-0.04401165131614211,-0.0028024240772956343,0.034731683133867174,-0.08405952388093836,-0.023233200266783334,-0.01316260705937048,0.06042996623230248,-0.08670566191112093,-0.028414368471546735,-0.09517723015078995,-0.2374218499956552,0.0758551783586578,0.09360314382731796,0.0101022463451281,0.0820651647347582,0.12187098657194885,0.08311645198076563,0.1352104748361589,-0.007292958239710767,-0.14336559542207122,0.04284933377454357,0.07730133279348135]
#  Top 20 Coefficients
# You should compares these relative to eachother
# +--------------------+-------------------+
# |feature             |coeff              |
# +--------------------+-------------------+
# |9-MFCCs1m           |3.9311476852966445 |
# |71-BPMessentia      |2.151041595111829  |
# |2-Energym           |1.9682591736954143 |
# |3-EnergyEntropym    |1.8121798716121589 |
# |53-MFCCs11std       |1.4708401355402414 |
# |54-MFCCs12std       |1.390340244492955  |
# |52-MFCCs10std       |1.2719176654504245 |
# |24-ChromaVector3m   |1.2069506566742794 |
# |5-SpectralSpreadm   |1.2030050420433844 |
# |50-MFCCs8std        |0.9026608054790878 |
# |6-SpectralEntropym  |0.9021041920633076 |
# |58-ChromaVector3std |0.8408491968759249 |
# |51-MFCCs9std        |0.6648756180006956 |
# |4-SpectralCentroidm |0.6626990869812579 |
# |22-ChromaVector1m   |0.5922273880439545 |
# |1-ZCRm              |0.5918404675957891 |
# |67-ChromaVector12std|0.535486305010547  |
# |33-ChromaVector12m  |0.5108309504278268 |
# |8-SpectralRolloffm  |0.38101571747345914|
# |36-Energystd        |0.3481119439241445 |
# +--------------------+-------------------+
# only showing top 20 rows
#
# None
#
# OneVsRest
# Intercept:  -3.8919336043721917
# Top 20 Coefficients:
# +--------------------+-------------------+
# |feature             |coeff              |
# +--------------------+-------------------+
# |9-MFCCs1m           |4.0628831153665805 |
# |71-BPMessentia      |2.2757392561341785 |
# |52-MFCCs10std       |1.6462920843566844 |
# |53-MFCCs11std       |1.6376956798273863 |
# |54-MFCCs12std       |1.552105973829511  |
# |50-MFCCs8std        |1.38882630907457   |
# |5-SpectralSpreadm   |1.378610271020026  |
# |58-ChromaVector3std |1.3232861824202158 |
# |22-ChromaVector1m   |1.1645831289129736 |
# |20-MFCCs12m         |0.979431802420677  |
# |24-ChromaVector3m   |0.9212260192944811 |
# |3-EnergyEntropym    |0.9059029314537917 |
# |43-MFCCs1std        |0.7971345531398034 |
# |27-ChromaVector6m   |0.7817012165647658 |
# |2-Energym           |0.7488179934151711 |
# |36-Energystd        |0.7317187075952312 |
# |67-ChromaVector12std|0.5881532540474702 |
# |65-ChromaVector10std|0.5561508071923452 |
# |12-MFCCs4m          |0.4793380557199752 |
# |47-MFCCs5std        |0.45999273108811295|
# +--------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.342756037945951
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |71-BPMessentia       |4.4011625385193485|
# |40-SpectralEntropystd|2.833269934996752 |
# |69-BPM               |2.506336958043033 |
# |44-MFCCs2std         |2.195602507800555 |
# |5-SpectralSpreadm    |2.0650913865317047|
# |49-MFCCs7std         |1.7553410424824658|
# |29-ChromaVector8m    |1.669865116157374 |
# |11-MFCCs3m           |1.6641315505778427|
# |42-SpectralRolloffstd|1.648964357359973 |
# |28-ChromaVector7m    |1.5657407768744227|
# |61-ChromaVector6std  |1.493761320591886 |
# |65-ChromaVector10std |1.2825804675016585|
# |34-ChromaDeviationm  |1.065800914077476 |
# |52-MFCCs10std        |1.0070368468598223|
# |3-EnergyEntropym     |0.8968937052309728|
# |24-ChromaVector3m    |0.8798267464324064|
# |68-ChromaDeviationstd|0.8550574134593346|
# |16-MFCCs8m           |0.7702040228367102|
# |48-MFCCs6std         |0.7355372103871395|
# |46-MFCCs4std         |0.6912864643572707|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.912547561981292
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |3-EnergyEntropym      |3.326857741068294 |
# |12-MFCCs4m            |2.8912835580262004|
# |52-MFCCs10std         |2.2501282431150167|
# |55-MFCCs13std         |1.9725830199207732|
# |36-Energystd          |1.8232439235727886|
# |17-MFCCs9m            |1.6967208360502148|
# |67-ChromaVector12std  |1.685956706322145 |
# |51-MFCCs9std          |1.664663953604927 |
# |40-SpectralEntropystd |1.463320805348741 |
# |25-ChromaVector4m     |1.3174113039905444|
# |57-ChromaVector2std   |1.2934760804230159|
# |45-MFCCs3std          |1.2826377261130284|
# |22-ChromaVector1m     |1.2812093489402125|
# |29-ChromaVector8m     |1.226344854377415 |
# |9-MFCCs1m             |1.020597832733885 |
# |39-SpectralSpreadstd  |1.008947992618728 |
# |10-MFCCs2m            |0.9115816739709602|
# |50-MFCCs8std          |0.9041282387008983|
# |38-SpectralCentroidstd|0.8317075608123088|
# |44-MFCCs2std          |0.7847008573726579|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  0.10022269782377213
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |3.1577306418164564|
# |10-MFCCs2m            |3.0685538296314423|
# |70-BPMconf            |2.7890040091689823|
# |36-Energystd          |2.568331083779043 |
# |53-MFCCs11std         |2.252000705539018 |
# |33-ChromaVector12m    |1.8688371566063577|
# |26-ChromaVector5m     |1.8628896973335063|
# |38-SpectralCentroidstd|1.748660259008212 |
# |23-ChromaVector2m     |1.6649980138632738|
# |67-ChromaVector12std  |1.2814403658004234|
# |64-ChromaVector9std   |1.2798179129623948|
# |71-BPMessentia        |1.2733117724489236|
# |58-ChromaVector3std   |1.271904835505179 |
# |34-ChromaDeviationm   |1.2568355487007281|
# |32-ChromaVector11m    |1.236116041578269 |
# |11-MFCCs3m            |1.219394687420638 |
# |55-MFCCs13std         |1.1248566783073748|
# |46-MFCCs4std          |1.1080468805807673|
# |68-ChromaDeviationstd |0.991061107703215 |
# |27-ChromaVector6m     |0.9610849539756147|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.165328792570368
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |2-Energym            |3.9663934123923057|
# |5-SpectralSpreadm    |3.6502119127454598|
# |59-ChromaVector4std  |3.154456791034429 |
# |43-MFCCs1std         |3.0500358438459085|
# |4-SpectralCentroidm  |2.055408348884511 |
# |42-SpectralRolloffstd|1.9867964975050298|
# |69-BPM               |1.4502417345760639|
# |40-SpectralEntropystd|1.2516527941408773|
# |24-ChromaVector3m    |1.107606789717938 |
# |63-ChromaVector8std  |1.078366502439833 |
# |10-MFCCs2m           |1.0515108548542147|
# |23-ChromaVector2m    |0.8999841667595558|
# |60-ChromaVector5std  |0.8910048465012776|
# |26-ChromaVector5m    |0.8790505740434547|
# |44-MFCCs2std         |0.7960321910278029|
# |34-ChromaDeviationm  |0.6331555891882019|
# |17-MFCCs9m           |0.6147014200907127|
# |64-ChromaVector9std  |0.5713665265634171|
# |20-MFCCs12m          |0.4720474189185739|
# |11-MFCCs3m           |0.4645543849006202|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -9.54919110085214
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |69-BPM               |3.817627355837352 |
# |34-ChromaDeviationm  |3.037843383196859 |
# |13-MFCCs5m           |3.0103357750759847|
# |45-MFCCs3std         |2.749537218010537 |
# |24-ChromaVector3m    |2.52040912422068  |
# |53-MFCCs11std        |2.111935040742058 |
# |17-MFCCs9m           |1.5907589423689916|
# |3-EnergyEntropym     |1.5195694915121927|
# |8-SpectralRolloffm   |1.4207776939361536|
# |36-Energystd         |1.3864587588998227|
# |29-ChromaVector8m    |1.3212779504086054|
# |51-MFCCs9std         |1.1684367017266144|
# |27-ChromaVector6m    |1.1390175222775858|
# |20-MFCCs12m          |1.1096703335433327|
# |44-MFCCs2std         |1.0240996628380437|
# |68-ChromaDeviationstd|0.9447502777928956|
# |4-SpectralCentroidm  |0.9226289331335129|
# |35-ZCRstd            |0.807992370013045 |
# |21-MFCCs13m          |0.7848875845210618|
# |2-Energym            |0.766522233328257 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.0864589070302
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |9-MFCCs1m          |4.331304843513305 |
# |43-MFCCs1std       |3.6062442845974063|
# |71-BPMessentia     |2.904211361840093 |
# |2-Energym          |2.2477452585640503|
# |57-ChromaVector2std|1.6165830353690671|
# |22-ChromaVector1m  |1.5356909782410195|
# |12-MFCCs4m         |1.3845856258955016|
# |11-MFCCs3m         |1.2951974242409574|
# |3-EnergyEntropym   |1.0958072524341866|
# |30-ChromaVector9m  |1.0949283590534649|
# |18-MFCCs10m        |1.0330490715335017|
# |5-SpectralSpreadm  |0.9986963699589154|
# |45-MFCCs3std       |0.9349147736750042|
# |62-ChromaVector7std|0.916345271212008 |
# |51-MFCCs9std       |0.9115005141877817|
# |16-MFCCs8m         |0.8213351749226315|
# |6-SpectralEntropym |0.7848147072890589|
# |37-EnergyEntropystd|0.6221797368296612|
# |58-ChromaVector3std|0.62117621663484  |
# |23-ChromaVector2m  |0.6167027756774504|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  4.923976755115253
# Top 20 Coefficients:
# +---------------------+-------------------+
# |feature              |coeff              |
# +---------------------+-------------------+
# |23-ChromaVector2m    |1.7025676140510468 |
# |25-ChromaVector4m    |1.5779372895498973 |
# |48-MFCCs6std         |1.4892200914411307 |
# |26-ChromaVector5m    |1.4796506115262773 |
# |18-MFCCs10m          |1.4429897706795467 |
# |37-EnergyEntropystd  |1.3200962427030472 |
# |19-MFCCs11m          |1.104168613237645  |
# |44-MFCCs2std         |1.0547240080684466 |
# |36-Energystd         |1.0321173020062324 |
# |69-BPM               |0.9644395370357418 |
# |41-SpectralFluxstd   |0.9383034708125302 |
# |15-MFCCs7m           |0.8348611502784611 |
# |10-MFCCs2m           |0.7776448036710525 |
# |68-ChromaDeviationstd|0.7538543111600291 |
# |5-SpectralSpreadm    |0.6327520147817047 |
# |52-MFCCs10std        |0.6027332505112015 |
# |28-ChromaVector7m    |0.5907707962771797 |
# |32-ChromaVector11m   |0.575743039707002  |
# |33-ChromaVector12m   |0.5265712463009747 |
# |55-MFCCs13std        |0.46037504731790174|
# +---------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.2314180326461655
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |11-MFCCs3m           |3.1683788621775926|
# |63-ChromaVector8std  |2.1753969669765665|
# |62-ChromaVector7std  |2.126929480428698 |
# |64-ChromaVector9std  |1.960863308722588 |
# |55-MFCCs13std        |1.9150825008976413|
# |40-SpectralEntropystd|1.8114275393288877|
# |17-MFCCs9m           |1.675191768382834 |
# |49-MFCCs7std         |1.5807633376789114|
# |60-ChromaVector5std  |1.5495928189773926|
# |43-MFCCs1std         |1.4990021632006192|
# |12-MFCCs4m           |1.4937329753945507|
# |57-ChromaVector2std  |1.4679351137061072|
# |32-ChromaVector11m   |1.3421529587576246|
# |48-MFCCs6std         |1.2773301021070156|
# |14-MFCCs6m           |1.2258054040498378|
# |26-ChromaVector5m    |1.184260809660206 |
# |19-MFCCs11m          |1.1724720811046065|
# |65-ChromaVector10std |1.1672060003525233|
# |9-MFCCs1m            |1.1316139625546942|
# |50-MFCCs8std         |1.1109986076968135|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.912775930697187
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |9-MFCCs1m             |4.920298618039024 |
# |3-EnergyEntropym      |4.351876954530879 |
# |71-BPMessentia        |2.6197437734909195|
# |36-Energystd          |1.8655176657101609|
# |38-SpectralCentroidstd|1.8387020043247764|
# |41-SpectralFluxstd    |1.5925834988028797|
# |60-ChromaVector5std   |1.5635599201018315|
# |43-MFCCs1std          |1.5540335734202702|
# |63-ChromaVector8std   |1.4481986384799364|
# |40-SpectralEntropystd |1.3296940954578196|
# |11-MFCCs3m            |1.2884496344689145|
# |62-ChromaVector7std   |1.2410311861761059|
# |23-ChromaVector2m     |1.1754567375702127|
# |17-MFCCs9m            |1.139476472090777 |
# |2-Energym             |1.0947291895637388|
# |61-ChromaVector6std   |1.0532731343829993|
# |58-ChromaVector3std   |0.9973346913657667|
# |44-MFCCs2std          |0.9789532454240981|
# |53-MFCCs11std         |0.9371134362122808|
# |42-SpectralRolloffstd |0.8633343319160931|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.820089410375927
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |56-ChromaVector1std |4.021610332556365 |
# |9-MFCCs1m           |2.7458001434298818|
# |43-MFCCs1std        |2.072500174139097 |
# |21-MFCCs13m         |2.0664539587438773|
# |18-MFCCs10m         |1.759621805900927 |
# |50-MFCCs8std        |1.6222931572182346|
# |62-ChromaVector7std |1.496141835670728 |
# |69-BPM              |1.4153728151413136|
# |48-MFCCs6std        |1.1727062308452023|
# |41-SpectralFluxstd  |1.0816736175752895|
# |65-ChromaVector10std|0.9379788605385866|
# |52-MFCCs10std       |0.9369930545168395|
# |58-ChromaVector3std |0.9159456074621126|
# |35-ZCRstd           |0.8914195581241193|
# |32-ChromaVector11m  |0.8887463825144292|
# |66-ChromaVector11std|0.882097947482415 |
# |60-ChromaVector5std |0.8670437233119019|
# |11-MFCCs3m          |0.8615869158865369|
# |39-SpectralSpreadstd|0.7896942407427513|
# |26-ChromaVector5m   |0.7212843770355326|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.998317136915442
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |70-BPMconf           |6.1189030389180115|
# |71-BPMessentia       |2.4091002390125746|
# |63-ChromaVector8std  |2.3382631381718584|
# |2-Energym            |2.1524160246723167|
# |67-ChromaVector12std |1.9896092528150988|
# |68-ChromaDeviationstd|1.978772039079158 |
# |9-MFCCs1m            |1.975756423088293 |
# |18-MFCCs10m          |1.856803473319274 |
# |48-MFCCs6std         |1.7797277210577658|
# |46-MFCCs4std         |1.619717855886721 |
# |69-BPM               |1.5811234395674   |
# |15-MFCCs7m           |1.3269757264778108|
# |59-ChromaVector4std  |1.2374368670136617|
# |3-EnergyEntropym     |1.1738099302932519|
# |53-MFCCs11std        |1.1604082325350256|
# |25-ChromaVector4m    |1.0970850507236811|
# |5-SpectralSpreadm    |1.0752923608360845|
# |14-MFCCs6m           |1.0138084990918161|
# |52-MFCCs10std        |0.9942129842222672|
# |28-ChromaVector7m    |0.8720784972520842|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  5.243067494940287
# Top 20 Coefficients:
# +----------------------+-------------------+
# |feature               |coeff              |
# +----------------------+-------------------+
# |13-MFCCs5m            |4.06564288256821   |
# |2-Energym             |3.6349338962926727 |
# |70-BPMconf            |2.662872128868669  |
# |7-SpectralFluxm       |2.592626281160951  |
# |15-MFCCs7m            |1.9560287089431827 |
# |1-ZCRm                |1.716881691874808  |
# |38-SpectralCentroidstd|1.49726729356994   |
# |28-ChromaVector7m     |1.4649804546658538 |
# |21-MFCCs13m           |1.3937155212788004 |
# |45-MFCCs3std          |1.3459969010929524 |
# |44-MFCCs2std          |1.0636519798010797 |
# |56-ChromaVector1std   |0.9882437988429157 |
# |19-MFCCs11m           |0.9152133479389822 |
# |71-BPMessentia        |0.8470074273695816 |
# |12-MFCCs4m            |0.7442376533249165 |
# |35-ZCRstd             |0.7357882744904005 |
# |30-ChromaVector9m     |0.6052259374980324 |
# |29-ChromaVector8m     |0.37342419088142637|
# |4-SpectralCentroidm   |0.37157937767939275|
# |66-ChromaVector11std  |0.34547147443455045|
# +----------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.32844360786717
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |55-MFCCs13std       |3.3395727793557413|
# |44-MFCCs2std        |3.265919973785819 |
# |69-BPM              |3.0899808654222585|
# |36-Energystd        |3.0586540942594693|
# |27-ChromaVector6m   |2.9027511595815896|
# |63-ChromaVector8std |2.484490284451734 |
# |18-MFCCs10m         |2.097062940390584 |
# |3-EnergyEntropym    |1.6531563371925804|
# |34-ChromaDeviationm |1.6079028463890628|
# |46-MFCCs4std        |1.578119052823811 |
# |14-MFCCs6m          |1.3936119117461385|
# |54-MFCCs12std       |1.2644526907908955|
# |48-MFCCs6std        |1.2344025634804496|
# |24-ChromaVector3m   |1.211203660682689 |
# |6-SpectralEntropym  |0.8786330072371986|
# |60-ChromaVector5std |0.8162834597564096|
# |2-Energym           |0.7650704506798333|
# |49-MFCCs7std        |0.7312638346426241|
# |65-ChromaVector10std|0.7189685050390493|
# |15-MFCCs7m          |0.6850273127359031|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.022003402617614
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |57-ChromaVector2std   |3.7700110545885486|
# |46-MFCCs4std          |2.3832091004958817|
# |11-MFCCs3m            |2.3219417000909446|
# |63-ChromaVector8std   |2.2250601778341914|
# |55-MFCCs13std         |2.1331416131609147|
# |71-BPMessentia        |2.065942903100569 |
# |35-ZCRstd             |1.9999882344398907|
# |36-Energystd          |1.7490712577698109|
# |64-ChromaVector9std   |1.7059967446019049|
# |38-SpectralCentroidstd|1.646136247473435 |
# |43-MFCCs1std          |1.2332648772948251|
# |3-EnergyEntropym      |1.1408587423957208|
# |54-MFCCs12std         |0.9545616591803643|
# |20-MFCCs12m           |0.9140461439901387|
# |58-ChromaVector3std   |0.8600620560878082|
# |1-ZCRm                |0.8526463140389036|
# |41-SpectralFluxstd    |0.806457711990647 |
# |14-MFCCs6m            |0.674388133754083 |
# |42-SpectralRolloffstd |0.6219619105647373|
# |32-ChromaVector11m    |0.6211345307597482|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.291108331017285
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |60-ChromaVector5std  |2.952078789808724 |
# |11-MFCCs3m           |2.6980439635180127|
# |49-MFCCs7std         |2.6172284380222925|
# |37-EnergyEntropystd  |2.4730757201103675|
# |39-SpectralSpreadstd |1.8760781431966334|
# |68-ChromaDeviationstd|1.872092710656486 |
# |36-Energystd         |1.8634730619152378|
# |58-ChromaVector3std  |1.4814412900706184|
# |70-BPMconf           |1.4759001568637666|
# |5-SpectralSpreadm    |1.4184633546077856|
# |30-ChromaVector9m    |1.322958294827646 |
# |23-ChromaVector2m    |1.3144139101287104|
# |47-MFCCs5std         |1.2440841447218258|
# |20-MFCCs12m          |1.112090028442682 |
# |9-MFCCs1m            |1.0975419524180847|
# |32-ChromaVector11m   |1.0002060967113033|
# |18-MFCCs10m          |0.9366324309006977|
# |54-MFCCs12std        |0.8902081195876874|
# |16-MFCCs8m           |0.8714064466512239|
# |29-ChromaVector8m    |0.8239622665150851|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.9708774188888465
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |43-MFCCs1std          |4.004974161774071 |
# |41-SpectralFluxstd    |3.635343021903377 |
# |7-SpectralFluxm       |3.437719447448806 |
# |29-ChromaVector8m     |2.750112223616144 |
# |71-BPMessentia        |2.05978090068858  |
# |21-MFCCs13m           |1.7415872023515746|
# |39-SpectralSpreadstd  |1.6125804524629885|
# |25-ChromaVector4m     |1.5979235941417675|
# |38-SpectralCentroidstd|1.5629767541335897|
# |33-ChromaVector12m    |1.5609162972916495|
# |45-MFCCs3std          |1.4702854697766858|
# |58-ChromaVector3std   |1.2600898552253164|
# |20-MFCCs12m           |1.19504618575318  |
# |23-ChromaVector2m     |1.1324574864269783|
# |27-ChromaVector6m     |1.0770916754788125|
# |32-ChromaVector11m    |1.0524360813129343|
# |42-SpectralRolloffstd |1.0232187802829853|
# |48-MFCCs6std          |0.924607150055442 |
# |31-ChromaVector10m    |0.8751009908118822|
# |37-EnergyEntropystd   |0.8258098682554516|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -0.7704781634892176
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |17-MFCCs9m            |3.156451419023145 |
# |36-Energystd          |2.328413415899129 |
# |27-ChromaVector6m     |2.2674318393838884|
# |10-MFCCs2m            |2.1542163230343996|
# |41-SpectralFluxstd    |2.125299339288123 |
# |64-ChromaVector9std   |1.8374987776639862|
# |26-ChromaVector5m     |1.8237308740835239|
# |54-MFCCs12std         |1.6648749266740768|
# |70-BPMconf            |1.6250649466683842|
# |42-SpectralRolloffstd |1.6149883975610508|
# |38-SpectralCentroidstd|1.5870798900178014|
# |51-MFCCs9std          |1.4244080658594387|
# |61-ChromaVector6std   |1.3900428836921586|
# |32-ChromaVector11m    |1.3872104692156655|
# |20-MFCCs12m           |1.1699335631111483|
# |14-MFCCs6m            |1.1361073987665007|
# |65-ChromaVector10std  |1.0452934200477466|
# |63-ChromaVector8std   |1.0332331247483397|
# |58-ChromaVector3std   |0.914167656442118 |
# |31-ChromaVector10m    |0.8415373046003093|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  1.5963168626014281
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |71-BPMessentia       |7.30507181189445  |
# |7-SpectralFluxm      |3.261851986808963 |
# |41-SpectralFluxstd   |2.8972096555091365|
# |69-BPM               |2.8591012339290915|
# |9-MFCCs1m            |2.489354841298382 |
# |62-ChromaVector7std  |2.4285475795845586|
# |66-ChromaVector11std |1.9829112642476292|
# |68-ChromaDeviationstd|1.8756451049167093|
# |67-ChromaVector12std |1.8689914706887307|
# |29-ChromaVector8m    |1.6425569041838832|
# |49-MFCCs7std         |1.5345626394544005|
# |57-ChromaVector2std  |1.4939810778209914|
# |27-ChromaVector6m    |1.3373871352824205|
# |31-ChromaVector10m   |1.2425743417329247|
# |63-ChromaVector8std  |1.1677250012487712|
# |17-MFCCs9m           |0.8653128779411356|
# |26-ChromaVector5m    |0.7187019764929434|
# |23-ChromaVector2m    |0.6970757345841577|
# |12-MFCCs4m           |0.6827097068266454|
# |20-MFCCs12m          |0.6657915036852744|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.830137284914625
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |47-MFCCs5std         |3.3716837358991785|
# |55-MFCCs13std        |2.928936847755918 |
# |39-SpectralSpreadstd |2.8315845840847405|
# |59-ChromaVector4std  |2.7491469860399005|
# |66-ChromaVector11std |2.266166749982157 |
# |63-ChromaVector8std  |2.1451680864149734|
# |45-MFCCs3std         |2.1270159945560208|
# |54-MFCCs12std        |1.8182131892130693|
# |16-MFCCs8m           |1.7518403301850605|
# |20-MFCCs12m          |1.714924729254046 |
# |68-ChromaDeviationstd|1.5321066765967382|
# |69-BPM               |1.4817678551373419|
# |25-ChromaVector4m    |1.459847204433874 |
# |37-EnergyEntropystd  |1.4391013446220537|
# |50-MFCCs8std         |1.3554711385224159|
# |34-ChromaDeviationm  |1.3190553882978433|
# |67-ChromaVector12std |1.302525136532983 |
# |51-MFCCs9std         |1.2641314935017396|
# |24-ChromaVector3m    |1.2327452496073337|
# |35-ZCRstd            |1.1926786629427555|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.2427550298005685
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |11-MFCCs3m            |2.4971935157286125|
# |35-ZCRstd             |1.6983100321533915|
# |56-ChromaVector1std   |1.6526214812739084|
# |44-MFCCs2std          |1.5353198410708433|
# |15-MFCCs7m            |1.4495753209675728|
# |57-ChromaVector2std   |1.4263884411340473|
# |38-SpectralCentroidstd|1.386027282039231 |
# |67-ChromaVector12std  |1.2775317074289285|
# |43-MFCCs1std          |1.252237113394479 |
# |13-MFCCs5m            |1.237965761106889 |
# |41-SpectralFluxstd    |1.1865612482417323|
# |42-SpectralRolloffstd |1.0273564228478382|
# |71-BPMessentia        |0.9464934989418277|
# |17-MFCCs9m            |0.9385703303403865|
# |54-MFCCs12std         |0.9324246749821651|
# |65-ChromaVector10std  |0.921944694376574 |
# |3-EnergyEntropym      |0.8562599445628091|
# |22-ChromaVector1m     |0.843548959600578 |
# |37-EnergyEntropystd   |0.7461501743585793|
# |25-ChromaVector4m     |0.7029124305423463|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.9578667242777295
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |22-ChromaVector1m     |2.156307623497065 |
# |12-MFCCs4m            |2.143441426613865 |
# |65-ChromaVector10std  |2.117371178729586 |
# |59-ChromaVector4std   |1.8058286358004028|
# |25-ChromaVector4m     |1.7603224137152989|
# |36-Energystd          |1.739018671077555 |
# |56-ChromaVector1std   |1.6819084434993004|
# |55-MFCCs13std         |1.5890807755127918|
# |38-SpectralCentroidstd|1.5242877259944465|
# |28-ChromaVector7m     |1.495109982201265 |
# |18-MFCCs10m           |1.3907414642051599|
# |15-MFCCs7m            |1.388023065088746 |
# |20-MFCCs12m           |1.317152376703771 |
# |10-MFCCs2m            |1.3017821951024162|
# |44-MFCCs2std          |1.2981903540215354|
# |30-ChromaVector9m     |1.2877342795859454|
# |41-SpectralFluxstd    |1.2558361798720583|
# |71-BPMessentia        |1.199532425893265 |
# |48-MFCCs6std          |1.142627200364657 |
# |19-MFCCs11m           |1.0914875853942856|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.051773265891262
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |5-SpectralSpreadm   |2.4082860865748614|
# |23-ChromaVector2m   |1.985203644381297 |
# |25-ChromaVector4m   |1.8759777458044984|
# |9-MFCCs1m           |1.8482012563547818|
# |19-MFCCs11m         |1.846852234339299 |
# |66-ChromaVector11std|1.7671768800346228|
# |71-BPMessentia      |1.6621190105957437|
# |56-ChromaVector1std |1.584005103099179 |
# |31-ChromaVector10m  |1.580274548894156 |
# |21-MFCCs13m         |1.5756801087581156|
# |62-ChromaVector7std |1.480346416353265 |
# |3-EnergyEntropym    |1.4307010181055166|
# |30-ChromaVector9m   |1.3668946800518635|
# |41-SpectralFluxstd  |1.2778539552834443|
# |59-ChromaVector4std |1.2640388125210391|
# |16-MFCCs8m          |1.2112874794857758|
# |4-SpectralCentroidm |1.0235926432085425|
# |60-ChromaVector5std |0.9784332461092329|
# |50-MFCCs8std        |0.7784116011832588|
# |7-SpectralFluxm     |0.7074709087296598|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# LinearSVC  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# RandomForestClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +----------------------+--------------------+
# |feature               |score               |
# +----------------------+--------------------+
# |71-BPMessentia        |0.09029637565801324 |
# |69-BPM                |0.04366950943614576 |
# |70-BPMconf            |0.030123602250491738|
# |1-ZCRm                |0.026431283529933382|
# |2-Energym             |0.022871890005094674|
# |39-SpectralSpreadstd  |0.022061660601790385|
# |48-MFCCs6std          |0.02172691489489035 |
# |44-MFCCs2std          |0.021000566835674656|
# |43-MFCCs1std          |0.019799179700163257|
# |54-MFCCs12std         |0.01954237337059729 |
# |3-EnergyEntropym      |0.01947937653446136 |
# |9-MFCCs1m             |0.019321666225636427|
# |38-SpectralCentroidstd|0.018491971775398002|
# |52-MFCCs10std         |0.015658416545830178|
# |55-MFCCs13std         |0.01551839109930199 |
# |53-MFCCs11std         |0.01513697498606153 |
# |41-SpectralFluxstd    |0.015084961975907371|
# |10-MFCCs2m            |0.014445181886988132|
# |4-SpectralCentroidm   |0.014317111717293374|
# |6-SpectralEntropym    |0.014292143061570678|
# +----------------------+--------------------+
# only showing top 20 rows
#
# None
# GBTClassifier  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# DecisionTreeClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +--------------------+--------------------+
# |feature             |score               |
# +--------------------+--------------------+
# |71-BPMessentia      |0.4668264538793044  |
# |44-MFCCs2std        |0.10410375139055597 |
# |7-SpectralFluxm     |0.08687496576991434 |
# |2-Energym           |0.068366581249166   |
# |52-MFCCs10std       |0.06635909060103168 |
# |9-MFCCs1m           |0.037077366098595334|
# |4-SpectralCentroidm |0.026333234777201495|
# |50-MFCCs8std        |0.024988538733969418|
# |39-SpectralSpreadstd|0.02238054126324267 |
# |37-EnergyEntropystd |0.01765125895728364 |
# |6-SpectralEntropym  |0.017037008392411807|
# |64-ChromaVector9std |0.015937146278359147|
# |47-MFCCs5std        |0.01341846420347092 |
# |10-MFCCs2m          |0.011185546224932657|
# |26-ChromaVector5m   |0.009091070645223255|
# |3-EnergyEntropym    |0.007761051704011575|
# |27-ChromaVector6m   |0.004607929831325788|
# |5-SpectralSpreadm   |0.0                 |
# |56-ChromaVector1std |0.0                 |
# |53-MFCCs11std       |0.0                 |
# +--------------------+--------------------+
# only showing top 20 rows
#
# None
#
# MultilayerPerceptronClassifier
# Model Weights:  12023
#
# !!!!!Final Results!!!!!!!!
# +------------------------------+------+
# |Classifier                    |Result|
# +------------------------------+------+
# |LogisticRegression            |43.53 |
# |OneVsRest                     |47.70 |
# |LinearSVC                     |N/A   |
# |NaiveBayes                    |31.60 |
# |RandomForestClassifier        |45.11 |
# |GBTClassifier                 |N/A   |
# |DecisionTreeClassifier        |35.05 |
# |MultilayerPerceptronClassifier|46.98 |
# +------------------------------+------+

# %% [markdown]
# ## Test 3: Feature Selection
#
# Looks like all our of our models saw a little bit of improvement from the transformations we applied. And overall the best performing model was the One vs Rest. Let's try to do do some feature selection to make it even better!
#
# Since we are using the One vs Rest algorithm backed by Logistic Regression, we can use Pyspark's Chi Squared Selector feature to select our features.

# %%
from pyspark.ml.feature import VectorSlicer
from pyspark.ml.feature import ChiSqSelector
from pyspark.ml.linalg import Vectors

classifiers = [OneVsRest()] 

#Select the top n features and view results
maximum = len(input_columns)
for n in range(10,maximum,10):
    print("Testing top n = ",n," features")
    
    # For Tree classifiers
#     best_n_features = RF_featureimportances.argsort()[-n:][::-1]
#     best_n_features= best_n_features.tolist() # convert to a list
#     vs = VectorSlicer(inputCol="features", outputCol="best_features", indices=best_n_features)
#     bestFeaturesDf = vs.transform(test2_data)

    # For Logistic regression or One vs Rest
    selector = ChiSqSelector(numTopFeatures=n, featuresCol="features",
                         outputCol="selectedFeatures", labelCol="label")
    bestFeaturesDf = selector.fit(test2_data).transform(test2_data)
    bestFeaturesDf = bestFeaturesDf.select("label","selectedFeatures")
    bestFeaturesDf = bestFeaturesDf.withColumnRenamed("selectedFeatures","features")

    # Collect features
    features = bestFeaturesDf.select(['features']).collect()

    # Split
    train,test = bestFeaturesDf.randomSplit([0.7,0.3])
    
    # Specify folds
    folds = 2

    #set up your results table
    columns = ['Classifier', 'Result']
    vals = [("Place Holder","N/A")]
    results = spark.createDataFrame(vals, columns)

    for classifier in classifiers:
        new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
        results = results.union(new_result)
    results = results.where("Classifier!='Place Holder'")
    results.show(100,False)
# Out:
# Testing top n =  10  features
#
# OneVsRest
# Intercept:  -4.643906478003987
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |1-ZCRm             |4.415959055821219  |
# |10-MFCCs2m         |2.121780215310632  |
# |8-SpectralRolloffm |1.0476577573145462 |
# |2-Energym          |0.4983981430613159 |
# |7-SpectralFluxm    |0.3691836362633929 |
# |4-SpectralCentroidm|-0.3578854295710102|
# |3-EnergyEntropym   |-1.7102339989860653|
# |5-SpectralSpreadm  |-3.4523321197742405|
# |9-MFCCs1m          |-3.617320526346736 |
# |6-SpectralEntropym |-7.10561706016476  |
# +-------------------+-------------------+
#
# None
# Intercept:  -9.200354818207408
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |9-MFCCs1m          |3.9338405569080956 |
# |10-MFCCs2m         |3.17010452345009   |
# |7-SpectralFluxm    |2.035904910285707  |
# |8-SpectralRolloffm |1.297690078932754  |
# |1-ZCRm             |1.0936771153422344 |
# |5-SpectralSpreadm  |0.9781759560453308 |
# |2-Energym          |0.9415585857251106 |
# |3-EnergyEntropym   |0.5668030022321581 |
# |6-SpectralEntropym |0.31049379926863724|
# |4-SpectralCentroidm|-0.7524556074650488|
# +-------------------+-------------------+
#
# None
# Intercept:  -2.7529986112966442
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |7-SpectralFluxm    |3.6312652607387554 |
# |1-ZCRm             |2.970739492491314  |
# |4-SpectralCentroidm|0.24839187534077994|
# |10-MFCCs2m         |-0.7458551258806332|
# |8-SpectralRolloffm |-0.8896696176178572|
# |6-SpectralEntropym |-0.9409720281448588|
# |5-SpectralSpreadm  |-1.0106013468135067|
# |3-EnergyEntropym   |-1.572419365721475 |
# |2-Energym          |-1.6989678472962337|
# |9-MFCCs1m          |-4.326965927807026 |
# +-------------------+-------------------+
#
# None
# Intercept:  0.32703847253010354
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |6-SpectralEntropym |2.242561913351558   |
# |8-SpectralRolloffm |1.6876757383524963  |
# |4-SpectralCentroidm|1.4251549624881767  |
# |10-MFCCs2m         |0.46757351782645085 |
# |7-SpectralFluxm    |-0.10819131437688537|
# |5-SpectralSpreadm  |-0.3106261687932579 |
# |3-EnergyEntropym   |-0.5153231613043882 |
# |1-ZCRm             |-1.552373507344516  |
# |2-Energym          |-3.094551614358247  |
# |9-MFCCs1m          |-5.438869536509168  |
# +-------------------+--------------------+
#
# None
# Intercept:  0.39551108375870475
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |8-SpectralRolloffm
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |6-SpectralEntropym |9.492366710665568  |
# |5-SpectralSpreadm  |2.2615743713168954 |
# |3-EnergyEntropym   |1.7113090919794658 |
# |10-MFCCs2m         |1.5432944042967465 |
# |4-SpectralCentroidm|0.9437129138826074 |
# |2-Energym          |0.6697746455009688 |
# |8-SpectralRolloffm |-0.6875331590241733|
# |7-SpectralFluxm    |-2.623056266647301 |
# |1-ZCRm             |-3.211201973905863 |
# |9-MFCCs1m          |-3.299163618234897 |
# +-------------------+-------------------+
#
# None
# Intercept:  -0.16824822074810805
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |6-SpectralEntropym |2.5475771652239065  |
# |4-SpectralCentroidm|2.102874838108267   |
# |3-EnergyEntropym   |1.6985314322217882  |
# |10-MFCCs2m         |0.22787493839842068 |
# |8-SpectralRolloffm |-0.06255618553829048|
# |2-Energym          |-0.6454882211562332 |
# |1-ZCRm             |-1.7765815022838216 |
# |7-SpectralFluxm    |-2.1906007396991094 |
# |5-SpectralSpreadm  |-2.436356789579282  |
# |9-MFCCs1m          |-4.940279719308922  |
# +-------------------+--------------------+
#
# None
# Intercept:  -6.260379212572195
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |10-MFCCs2m         |9.28601836749941   |
# |6-SpectralEntropym |8.004465156947491  |
# |9-MFCCs1m          |3.1359157752696363 |
# |4-SpectralCentroidm|1.6234701342721207 |
# |3-EnergyEntropym   |0.22673702211956137|
# |1-ZCRm             |-0.8887098795371333|
# |5-SpectralSpreadm  |-1.428287243590254 |
# |2-Energym          |-1.4858380780447915|
# |8-SpectralRolloffm |-2.880791324888921 |
# |7-SpectralFluxm    |-5.7410949961611255|
# +-------------------+-------------------+
#
# None
# Intercept:  -3.816623014204878
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |7-SpectralFluxm    |5.05541257555118   |
# |3-EnergyEntropym   |1.885021999898123  |
# |5-SpectralSpreadm  |1.3150539448894345 |
# |9-MFCCs1m          |0.9770635010823187 |
# |4-SpectralCentroidm|0.8997821599678754 |
# |8-SpectralRolloffm |0.7738666273560385 |
# |2-Energym          |-0.4870101355095621|
# |1-ZCRm             |-1.7795649607208788|
# |10-MFCCs2m         |-3.249604810848458 |
# |6-SpectralEntropym |-4.425902555530761 |
# +-------------------+-------------------+
#
# None
# Intercept:  -1.393600513870164
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |5-SpectralSpreadm  |3.101344898522038  |
# |2-Energym          |2.2693163440913597 |
# |6-SpectralEntropym |1.3751659557197053 |
# |10-MFCCs2m         |1.3084098615372848 |
# |1-ZCRm             |-0.7412378174333653|
# |8-SpectralRolloffm |-1.3258293422541105|
# |7-SpectralFluxm    |-1.8065847678786005|
# |3-EnergyEntropym   |-2.0226320073358273|
# |4-SpectralCentroidm|-3.110597143477764 |
# |9-MFCCs1m          |-5.402349096559562 |
# +-------------------+-------------------+
#
# None
# Intercept:  0.21747718057995033
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |6-SpectralEntropym |4.263871490901343   |
# |10-MFCCs2m         |1.0649250283587983  |
# |3-EnergyEntropym   |0.964238129532616   |
# |5-SpectralSpreadm  |-0.36816515313473874|
# |4-SpectralCentroidm|-0.6896432275788128 |
# |8-SpectralRolloffm |-0.8905680844849624 |
# |2-Energym          |-1.4934257898194476 |
# |1-ZCRm             |-1.7004509245221728 |
# |9-MFCCs1m          |-2.601278402580763  |
# |7-SpectralFluxm    |-4.772051826175713  |
# +-------------------+--------------------+
#
# None
# Intercept:  -3.0838803498753267
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |1-ZCRm             |4
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |9-MFCCs1m             |4.577122286300511 |
# |3-EnergyEntropym      |4.241103249274742 |
# |43-MFCCs1std          |3.369179418445728 |
# |70-BPMconf            |2.3437199220423577|
# |63-ChromaVector8std   |1.9468823561917012|
# |38-SpectralCentroidstd|1.6257745359936533|
# |2-Energym             |1.548707483125461 |
# |44-MFCCs2std          |1.5109332092620114|
# |62-ChromaVector7std   |1.337031024974965 |
# |61-ChromaVector6std   |1.3349983142594708|
# |67-ChromaVector12std  |1.3163072860593354|
# |41-SpectralFluxstd    |1.243118151240007 |
# |17-MFCCs9m            |1.1610292766810248|
# |60-ChromaVector5std   |1.100573022863885 |
# |58-ChromaVector3std   |1.0706754959769647|
# |53-MFCCs11std         |0.9263752954536071|
# |42-SpectralRolloffstd |0.9136866647700234|
# |36-Energystd          |0.9013460030413039|
# |55-MFCCs13std         |0.8755142385606851|
# |46-MFCCs4std          |0.8560230247510773|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -8.333457248249651
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |56-ChromaVector1std |5.67160993815981  |
# |69-BPM              |3.5996791312713796|
# |9-MFCCs1m           |3.10709648606814  |
# |21-MFCCs13m         |2.1695873432864192|
# |43-MFCCs1std        |1.9652027003544015|
# |26-ChromaVector5m   |1.837604127441152 |
# |50-MFCCs8std        |1.7933226924699313|
# |45-MFCCs3std        |1.7886360887238102|
# |58-ChromaVector3std |1.6407613706946786|
# |62-ChromaVector7std |1.4901329587640872|
# |11-MFCCs3m          |1.4317029154840155|
# |18-MFCCs10m         |1.3077962434712207|
# |35-ZCRstd           |1.2137174042387797|
# |52-MFCCs10std       |1.1204541392842557|
# |48-MFCCs6std        |1.0494062666669397|
# |13-MFCCs5m          |0.9350805079539707|
# |39-SpectralSpreadstd|0.9298745972362473|
# |59-ChromaVector4std |0.8592401084302876|
# |32-ChromaVector11m  |0.8588272123617433|
# |66-ChromaVector11std|0.7517500478963003|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1839295904243605
# Top 20 Coefficients:
# +---------------------+-------------------+
# |feature              |coeff              |
# +---------------------+-------------------+
# |63-ChromaVector8std  |3.144151521298136  |
# |67-ChromaVector12std |2.5807614726823753 |
# |48-MFCCs6std         |2.2999947546427313 |
# |68-ChromaDeviationstd|2.2984081672628682 |
# |14-MFCCs6m           |2.239319709998743  |
# |2-Energym            |2.184910421207933  |
# |9-MFCCs1m            |2.014416590982887  |
# |69-BPM               |2.007998424526858  |
# |25-ChromaVector4m    |1.6726200439484664 |
# |5-SpectralSpreadm    |1.638544170376377  |
# |52-MFCCs10std        |1.5470127084589667 |
# |28-ChromaVector7m    |1.4461110676973017 |
# |70-BPMconf           |1.3940842891451741 |
# |1-ZCRm               |0.8643513551777513 |
# |3-EnergyEntropym     |0.8600216451020031 |
# |62-ChromaVector7std  |0.7218010781309309 |
# |13-MFCCs5m           |0.662894008008887  |
# |6-SpectralEntropym   |0.5499286933216467 |
# |35-ZCRstd            |0.5043160204771107 |
# |51-MFCCs9std         |0.44217573994506876|
# +---------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  8.382589693240353
# Top 20 Coefficients:
# +----------------------+--------------------+
# |feature               |coeff               |
# +----------------------+--------------------+
# |13-MFCCs5m            |3.4720789020371323  |
# |2-Energym             |3.4285749765383966  |
# |7-SpectralFluxm       |2.93171754268615    |
# |1-ZCRm                |2.314366009345464   |
# |15-MFCCs7m            |1.7811895308450236  |
# |45-MFCCs3std          |1.6080135527519415  |
# |38-SpectralCentroidstd|1.369910407457196   |
# |28-ChromaVector7m     |1.3073028129158772  |
# |62-ChromaVector7std   |1.1302670772787164  |
# |70-BPMconf            |0.9534218579054378  |
# |24-ChromaVector3m     |0.8838655178840955  |
# |33-ChromaVector12m    |0.6871859371755439  |
# |21-MFCCs13m           |0.6645206289053835  |
# |4-SpectralCentroidm   |0.404647517643301   |
# |12-MFCCs4m            |0.3892026061941056  |
# |35-ZCRstd             |0.34100581101658156 |
# |23-ChromaVector2m     |0.2871733214798926  |
# |66-ChromaVector11std  |0.28550303634806035 |
# |8-SpectralRolloffm    |0.22834839462838916 |
# |56-ChromaVector1std   |-0.03103420993178999|
# +----------------------+--------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.092356238356028
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |69-BPM             |3.857524438568184 |
# |44-MFCCs2std       |3.5955217245389752|
# |55-MFCCs13std      |2.6304109945415055|
# |18-MFCCs10m        |2.5026166859405996|
# |36-Energystd       |2.496100609701152 |
# |3-EnergyEntropym   |2.473179951063456 |
# |27-ChromaVector6m  |2.2153961867610135|
# |63-ChromaVector8std|2.0158360836500266|
# |34-ChromaDeviationm|1.7447204972776016|
# |54-MFCCs12std      |1.7077408935448748|
# |60-ChromaVector5std|1.22453560887883  |
# |48-MFCCs6std       |1.1658390921077275|
# |52-MFCCs10std      |1.0588243654187635|
# |14-MFCCs6m         |1.0435069706538485|
# |24-ChromaVector3m  |1.0413353393210751|
# |30-ChromaVector9m  |1.031214995000176 |
# |6-SpectralEntropym |0.9269953203027139|
# |2-Energym          |0.9133442674431071|
# |29-ChromaVector8m  |0.6591246861227014|
# |46-MFCCs4std       |0.5381646770815077|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.0695329196129055
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |57-ChromaVector2std   |4.128372509906141 |
# |46-MFCCs4std          |3.247202725757115 |
# |11-MFCCs3m            |2.4734247727996834|
# |63-ChromaVector8std   |2.4502890618223017|
# |35-ZCRstd             |2.346741866086194 |
# |43-MFCCs1std          |2.1596225364310997|
# |70-BPMconf            |1.7938905541571732|
# |14-MFCCs6m            |1.7806520432879849|
# |38-SpectralCentroidstd|1.51577320446196  |
# |64-ChromaVector9std   |1.504503732029652 |
# |59-ChromaVector4std   |1.430095088098149 |
# |20-MFCCs12m           |1.2059307894329818|
# |1-ZCRm                |1.1108577935587822|
# |54-MFCCs12std         |1.0595217482679211|
# |3-EnergyEntropym      |1.0138017787027693|
# |40-SpectralEntropystd |0.90667499789327  |
# |13-MFCCs5m            |0.8863811927884528|
# |53-MFCCs11std         |0.825988761527618 |
# |26-ChromaVector5m     |0.7686604004487358|
# |55-MFCCs13std         |0.742522214181185 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.073813654182578
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |37-EnergyEntropystd  |3.1528085805475525|
# |58-ChromaVector3std  |2.7690778981979776|
# |68-ChromaDeviationstd|2.7467587141763437|
# |60-ChromaVector5std  |2.600925655939417 |
# |36-Energystd         |2.3055534955911483|
# |11-MFCCs3m           |1.9651877875228094|
# |39-SpectralSpreadstd |1.8773364104327426|
# |9-MFCCs1m            |1.7251737044548823|
# |53-MFCCs11std        |1.4532605263923335|
# |32-ChromaVector11m   |1.4441899644488772|
# |47-MFCCs5std         |1.3718794817424809|
# |28-ChromaVector7m    |1.3661427314521624|
# |30-ChromaVector9m    |1.2061046509179818|
# |49-MFCCs7std         |1.1719662256490218|
# |20-MFCCs12m          |1.0452398275033388|
# |70-BPMconf           |1.0186007810871238|
# |66-ChromaVector11std |0.9752274662747087|
# |61-ChromaVector6std  |0.9683201619039403|
# |23-ChromaVector2m    |0.9477880064904955|
# |64-ChromaVector9std  |0.9304696622779441|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.017877643864703
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |41-SpectralFluxstd    |3.896430015409515 |
# |7-SpectralFluxm       |3.354275132824542 |
# |43-MFCCs1std          |2.947430521772237 |
# |21-MFCCs13m           |1.9022783079331027|
# |59-ChromaVector4std   |1.7268216783176038|
# |38-SpectralCentroidstd|1.6211938907910644|
# |39-SpectralSpreadstd  |1.5887113405041566|
# |70-BPMconf            |1.5517592315629165|
# |25-ChromaVector4m     |1.3662448565272154|
# |33-ChromaVector12m    |1.33135895290616  |
# |45-MFCCs3std          |1.3292820741912212|
# |23-ChromaVector2m     |1.2457297666572038|
# |30-ChromaVector9m     |1.2037394883569583|
# |15-MFCCs7m            |1.0618447728800349|
# |29-ChromaVector8m     |1.0100916078291702|
# |20-MFCCs12m           |0.9615198657886163|
# |49-MFCCs7std          |0.9542951881437024|
# |48-MFCCs6std          |0.8462614360399956|
# |10-MFCCs2m            |0.8143457587144373|
# |34-ChromaDeviationm   |0.7489673950402171|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.025076996808243
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |36-Energystd          |3.0006346231213015|
# |38-SpectralCentroidstd|2.2998238593326854|
# |10-MFCCs2m            |2.203978090286196 |
# |32-ChromaVector11m    |1.7413538245587956|
# |42-SpectralRolloffstd |1.7078121159549526|
# |40-SpectralEntropystd |1.6894769110058374|
# |17-MFCCs9m            |1.6631518368181102|
# |51-MFCCs9std          |1.5848937983148315|
# |55-MFCCs13std         |1.5589398965759227|
# |21-MFCCs13m           |1.4248883738570846|
# |41-SpectralFluxstd    |1.3444116901684071|
# |58-ChromaVector3std   |1.2902506874202517|
# |27-ChromaVector6m     |1.2330290368013677|
# |26-ChromaVector5m     |1.2227275089371048|
# |13-MFCCs5m            |1.1734233978059398|
# |31-ChromaVector10m    |1.162647844970797 |
# |65-ChromaVector10std  |1.1532872947529769|
# |20-MFCCs12m           |0.9577744319147773|
# |12-MFCCs4m            |0.9202857723139803|
# |54-MFCCs12std         |0.8243487254474139|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.5520103857181595
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |70-BPMconf           |8.13084126672263  |
# |29-ChromaVector8m    |3.716247708586716 |
# |7-SpectralFluxm      |2.8479946980598836|
# |41-SpectralFluxstd   |2.659498499034043 |
# |62-ChromaVector7std  |2.5043667165004875|
# |9-MFCCs1m            |2.3727046439135266|
# |69-BPM               |2.316793167056505 |
# |66-ChromaVector11std |1.9945687087932757|
# |68-ChromaDeviationstd|1.824749954626197 |
# |20-MFCCs12m          |1.8139915542962166|
# |67-ChromaVector12std |1.6572874944338238|
# |27-ChromaVector6m    |1.5700263898493698|
# |49-MFCCs7std         |1.1887080899639437|
# |36-Energystd         |1.107452864411465 |
# |17-MFCCs9m           |1.0818312275877333|
# |31-ChromaVector10m   |1.0760586077410719|
# |57-ChromaVector2std  |1.0385367388752746|
# |63-ChromaVector8std  |0.9673789545739052|
# |61-ChromaVector6std  |0.8163240601097624|
# |33-ChromaVector12m   |0.6974681594112527|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.848376372153904
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |47-MFCCs5std         |3.253415652132016 |
# |39-SpectralSpreadstd |2.883468381860299 |
# |55-MFCCs13std        |2.879315849503645 |
# |45-MFCCs3std         |2.5445878137678175|
# |59-ChromaVector4std  |2.259557865761283 |
# |67-ChromaVector12std |2.1560740027993437|
# |63-ChromaVector8std  |2.0802812612998216|
# |54-MFCCs12std        |2.07928292095255  |
# |34-ChromaDeviationm  |1.771780198411652 |
# |66-ChromaVector11std |1.7548553002812755|
# |37-EnergyEntropystd  |1.6932437490943844|
# |27-ChromaVector6m    |1.6621319840927984|
# |15-MFCCs7m           |1.628641148174749 |
# |69-BPM               |1.603335222448701 |
# |25-ChromaVector4m    |1.5395803151984848|
# |32-ChromaVector11m   |1.506212515845432 |
# |68-ChromaDeviationstd|1.4508134368832422|
# |51-MFCCs9std         |1.403538982254531 |
# |16-MFCCs8m           |1.37284529894698  |
# |12-MFCCs4m           |1.2607926556242626|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.8548734654380166
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |30-ChromaVector9m     |2.97107773766247  |
# |35-ZCRstd             |2.638605276419578 |
# |38-SpectralCentroidstd|1.7647515408887346|
# |25-ChromaVector4m     |1.663877087011608 |
# |17-MFCCs9m            |1.5347400642767501|
# |11-MFCCs3m            |1.4675451499366057|
# |41-SpectralFluxstd    |1.2939602277371893|
# |44-MFCCs2std          |1.1454899689580231|
# |37-EnergyEntropystd   |1.1453868999933179|
# |70-BPMconf            |1.139462537676901 |
# |56-ChromaVector1std   |1.0149176053805729|
# |43-MFCCs1std          |1.014622503215206 |
# |42-SpectralRolloffstd |0.9250043071579404|
# |22-ChromaVector1m     |0.8700964807213173|
# |10-MFCCs2m            |0.860686804978804 |
# |16-MFCCs8m            |0.8481951437699439|
# |60-ChromaVector5std   |0.7798572850468357|
# |5-SpectralSpreadm     |0.6017901997017863|
# |20-MFCCs12m           |0.5965504518910909|
# |36-Energystd          |0.5627010690507055|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.8296397727663316
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |15-MFCCs7m            |2.5546301985525783|
# |59-ChromaVector4std   |2.293469790889639 |
# |18-MFCCs10m           |1.8987602819530374|
# |44-MFCCs2std          |1.793742248338522 |
# |36-Energystd          |1.7465644859354024|
# |21-MFCCs13m           |1.5527344240525993|
# |25-ChromaVector4m     |1.5236793840960825|
# |41-SpectralFluxstd    |1.3825796635488674|
# |33-ChromaVector12m    |1.3810949813546125|
# |22-ChromaVector1m     |1.3301336581561787|
# |42-SpectralRolloffstd |1.1797096344181217|
# |45-MFCCs3std          |1.1732437842368493|
# |12-MFCCs4m            |1.1664731853428014|
# |56-ChromaVector1std   |1.1589918550869645|
# |65-ChromaVector10std  |1.1480223548245223|
# |9-MFCCs1m             |1.0266540016466412|
# |55-MFCCs13std         |0.9528485598374924|
# |28-ChromaVector7m     |0.9283162850267279|
# |29-ChromaVector8m     |0.890432126773422 |
# |38-SpectralCentroidstd|0.8892527438867316|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.270214516220869
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |5-SpectralSpreadm   |2.1404268729808766|
# |9-MFCCs1m           |2.126420057010777 |
# |62-ChromaVector7std |1.9380629775809037|
# |59-ChromaVector4std |1.8957328843148382|
# |19-MFCCs11m         |1.8340270275583164|
# |66-ChromaVector11std|1.8121519833296493|
# |23-ChromaVector2m   |1.7842514657109194|
# |60-ChromaVector5std |1.7432378010798344|
# |3-EnergyEntropym    |1.6936326623488775|
# |25-ChromaVector4m   |1.6844933284559371|
# |56-ChromaVector1std |1.55329088381122  |
# |70-BPMconf          |1.2820628751571388|
# |16-MFCCs8m          |1.2598453803659253|
# |30-ChromaVector9m   |1.1795482624801596|
# |4-SpectralCentroidm |1.117601562568818 |
# |21-MFCCs13m         |1.1036548632017587|
# |31-ChromaVector10m  |1.0877941622954777|
# |27-ChromaVector6m   |1.017616857490061 |
# |20-MFCCs12m         |0.9862825463615114|
# |33-ChromaVector12m  |0.9552465718553577|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# +----------+------+
# |Classifier|Result|
# +----------+------+
# |OneVsRest |44.41 |
# +----------+------+

# %% [markdown]
# # Results
#
# Let's see if we can improve upon the results above of 45.94%.
#
# - 10 features = 32.27% (going down)
# - 20 features = 39.23% (going down)
# - 30 features = 39.24% (going down)
# - 40 features = 42.61% (going down)
# - 50 features = 43.52% (going down)
# - 60 features = 42.42% (going down)
# - 70 features = 40.22% (going down)
#
# **Take away:** looks like we actually never beat our baseline so let's stick with the 71 features. Setting a random seed might have helped with variability we saw here.
#
# ## Train final model
#
# Now we can finally train our final model with the optimal set of features!

# %%
from pyspark.ml.feature import VectorSlicer
from pyspark.ml.feature import ChiSqSelector
from pyspark.ml.linalg import Vectors

classifiers = [OneVsRest()] 

#Select the top n features and view results
n = 71

# For Logistic regression or One vs Rest
selector = ChiSqSelector(numTopFeatures=n, featuresCol="features",
                     outputCol="selectedFeatures", labelCol="label")
bestFeaturesDf = selector.fit(test2_data).transform(test2_data)
bestFeaturesDf = bestFeaturesDf.select("label","selectedFeatures")
bestFeaturesDf = bestFeaturesDf.withColumnRenamed("selectedFeatures","features")

# Collect features
features = bestFeaturesDf.select(['features']).collect()

# Split
train,test = bestFeaturesDf.randomSplit([0.7,0.3])

# Specify folds
folds = 2

#set up your results table
columns = ['Classifier', 'Result']
vals = [("Place Holder","N/A")]
results = spark.createDataFrame(vals, columns)

for classifier in classifiers:
    new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
    results = results.union(new_result)
results = results.where("Classifier!='Place Holder'")
results.show(100,False)
# Out:
#
# OneVsRest
# Intercept:  -8.319596385105829
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |9-MFCCs1m          |4.077336409619766 |
# |18-MFCCs10m        |2.1738604756808995|
# |71-BPMessentia     |2.1599398326149344|
# |5-SpectralSpreadm  |2.0296717417525105|
# |22-ChromaVector1m  |1.587251315043954 |
# |3-EnergyEntropym   |1.5757250062249344|
# |63-ChromaVector8std|1.531564961278887 |
# |43-MFCCs1std       |1.4356119063326684|
# |54-MFCCs12std      |1.4186406037976926|
# |2-Energym          |1.4080433150574294|
# |12-MFCCs4m         |1.287790547386133 |
# |52-MFCCs10std      |1.2709225795851873|
# |24-ChromaVector3m  |1.2231815809624773|
# |50-MFCCs8std       |1.1324536035602508|
# |13-MFCCs5m         |0.9906259652937311|
# |53-MFCCs11std      |0.9555987332555225|
# |15-MFCCs7m         |0.9425494420207089|
# |58-ChromaVector3std|0.8590563843048206|
# |20-MFCCs12m        |0.8435482443962519|
# |64-ChromaVector9std|0.7990546950934396|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.7796261454114677
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |71-BPMessentia       |4.747442465574782 |
# |40-SpectralEntropystd|2.7032486816863157|
# |69-BPM               |2.436280755938012 |
# |34-ChromaDeviationm  |2.2182224562658983|
# |44-MFCCs2std         |2.1243214511433854|
# |48-MFCCs6std         |1.9703402843253435|
# |24-ChromaVector3m    |1.7018086317690255|
# |29-ChromaVector8m    |1.6265053076860385|
# |28-ChromaVector7m    |1.5817745833391836|
# |5-SpectralSpreadm    |1.5760221663676202|
# |42-SpectralRolloffstd|1.5552190763649318|
# |49-MFCCs7std         |1.3132010227828264|
# |68-ChromaDeviationstd|1.2364112379088754|
# |65-ChromaVector10std |1.22301976304076  |
# |32-ChromaVector11m   |1.1303824994645715|
# |9-MFCCs1m            |0.8690766909807386|
# |57-ChromaVector2std  |0.7742161669963594|
# |3-EnergyEntropym     |0.6921740015951097|
# |11-MFCCs3m           |0.5397390864821684|
# |51-MFCCs9std         |0.4754502790941108|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.371576263754931
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |3-EnergyEntropym      |3.232990008182776 |
# |36-Energystd          |2.680178723352531 |
# |12-MFCCs4m            |2.4233209016264072|
# |51-MFCCs9std          |2.3356390756059344|
# |55-MFCCs13std         |1.7280552276644803|
# |63-ChromaVector8std   |1.543600527180802 |
# |17-MFCCs9m            |1.3168226973817954|
# |10-MFCCs2m            |1.2735574461266834|
# |9-MFCCs1m             |1.2667012437656233|
# |54-MFCCs12std         |1.2353805268874931|
# |52-MFCCs10std         |1.2100582200585093|
# |39-SpectralSpreadstd  |1.192496006228269 |
# |29-ChromaVector8m     |1.1909164153094196|
# |38-SpectralCentroidstd|1.121756183712263 |
# |67-ChromaVector12std  |1.0869688778660167|
# |40-SpectralEntropystd |1.0749116862470998|
# |31-ChromaVector10m    |0.9957836146227762|
# |22-ChromaVector1m     |0.8607496285785837|
# |60-ChromaVector5std   |0.8387193995377112|
# |53-MFCCs11std         |0.827129001053472 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.560694664670865
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |3.4971557463245633|
# |10-MFCCs2m            |2.5975956528719824|
# |70-BPMconf            |2.286239601526417 |
# |38-SpectralCentroidstd|2.2314518405732104|
# |11-MFCCs3m            |1.9465475664682854|
# |33-ChromaVector12m    |1.799551364488261 |
# |71-BPMessentia        |1.6691813404880351|
# |36-Energystd          |1.660473359677088 |
# |34-ChromaDeviationm   |1.6324488046760384|
# |32-ChromaVector11m    |1.5087046364372043|
# |64-ChromaVector9std   |1.5063302921922344|
# |63-ChromaVector8std   |1.4674678502690515|
# |60-ChromaVector5std   |1.4581605182817374|
# |57-ChromaVector2std   |1.147464853756323 |
# |68-ChromaDeviationstd |1.0243177317378944|
# |55-MFCCs13std         |0.9925489496588784|
# |35-ZCRstd             |0.9916485463537856|
# |50-MFCCs8std          |0.9633312435867165|
# |21-MFCCs13m           |0.7595443959712523|
# |42-SpectralRolloffstd |0.6976841506392203|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.3019712511466817
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |2-Energym            |4.254775251794472 |
# |5-SpectralSpreadm    |3.9219950175813065|
# |43-MFCCs1std         |3.2997467539371863|
# |4-SpectralCentroidm  |1.9872732650413318|
# |42-SpectralRolloffstd|1.9544999753197991|
# |44-MFCCs2std         |1.7742387260610968|
# |59-ChromaVector4std  |1.5641780711617044|
# |10-MFCCs2m           |1.4101814554586383|
# |40-SpectralEntropystd|1.3070231978611004|
# |69-BPM               |1.166906360047409 |
# |14-MFCCs6m           |1.06603931266664  |
# |24-ChromaVector3m    |1.0040341323843889|
# |33-ChromaVector12m   |0.9724756085710975|
# |20-MFCCs12m          |0.875308121653792 |
# |9-MFCCs1m            |0.8685559065649446|
# |66-ChromaVector11std |0.8585254749709352|
# |60-ChromaVector5std  |0.8508320942999462|
# |17-MFCCs9m           |0.7066301676043594|
# |34-ChromaDeviationm  |0.681586579955322 |
# |48-MFCCs6std         |0.6380457257422042|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -9.524010960074111
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |69-BPM               |4.491633769857885 |
# |13-MFCCs5m           |3.1369493307507628|
# |24-ChromaVector3m    |2.657279188859488 |
# |34-ChromaDeviationm  |2.614863097627287 |
# |68-ChromaDeviationstd|2.194096224807148 |
# |29-ChromaVector8m    |1.9913759543184162|
# |3-EnergyEntropym     |1.9263115299297957|
# |45-MFCCs3std         |1.9100875460340052|
# |27-ChromaVector6m    |1.9045236738538867|
# |65-ChromaVector10std |1.6620868372685542|
# |47-MFCCs5std         |1.6399439122501651|
# |8-SpectralRolloffm   |1.5574511832935123|
# |36-Energystd         |1.3828221785870687|
# |20-MFCCs12m          |1.2202356631350397|
# |4-SpectralCentroidm  |1.1289207687809264|
# |25-ChromaVector4m    |1.0708031700084983|
# |12-MFCCs4m           |1.0326301877662738|
# |58-ChromaVector3std  |1.0276678511459991|
# |16-MFCCs8m           |0.9661446893361243|
# |23-ChromaVector2m    |0.8709693383744984|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0971794897489766
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |9-MFCCs1m          |3.960030522824197 |
# |43-MFCCs1std       |3.6485221823506895|
# |22-ChromaVector1m  |3.015947150407656 |
# |71-BPMessentia     |2.7299087509720272|
# |2-Energym          |2.2782115959858578|
# |31-ChromaVector10m |1.6824209431880277|
# |46-MFCCs4std       |1.554663079094402 |
# |29-ChromaVector8m  |1.5224757802869442|
# |51-MFCCs9std       |1.2453234431713653|
# |6-SpectralEntropym |1.1085484422337413|
# |37-EnergyEntropystd|1.1053881226636755|
# |11-MFCCs3m         |1.048019669681269 |
# |57-ChromaVector2std|0.9984677881891493|
# |12-MFCCs4m         |0.960258649980668 |
# |19-MFCCs11m        |0.9440231959104763|
# |18-MFCCs10m        |0.9146123523196743|
# |58-ChromaVector3std|0.8673304566573872|
# |50-MFCCs8std       |0.8065542147205981|
# |3-EnergyEntropym   |0.7499918506734918|
# |16-MFCCs8m         |0.6480166908682143|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  5.367321026701269
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |48-MFCCs6std         |1.989327688142602 |
# |32-ChromaVector11m   |1.6635079264145392|
# |26-ChromaVector5m    |1.6449696178306925|
# |10-MFCCs2m           |1.522099045121353 |
# |18-MFCCs10m          |1.4977869789704068|
# |62-ChromaVector7std  |1.392780481592887 |
# |30-ChromaVector9m    |1.2834607747309728|
# |23-ChromaVector2m    |1.2540656712523093|
# |69-BPM               |1.190755432283886 |
# |25-ChromaVector4m    |1.1710108843264437|
# |5-SpectralSpreadm    |1.157326426757767 |
# |54-MFCCs12std        |1.0256063715335035|
# |41-SpectralFluxstd   |0.9536695186267462|
# |36-Energystd         |0.9003181397699097|
# |68-ChromaDeviationstd|0.8693955656101828|
# |44-MFCCs2std         |0.8670544083514329|
# |11-MFCCs3m           |0.8431895948912548|
# |33-ChromaVector12m   |0.8102854368778286|
# |55-MFCCs13std        |0.6978536398885163|
# |37-EnergyEntropystd  |0.6597580781654813|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.514020832302659
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |11-MFCCs3m           |2.7411318196548846|
# |63-ChromaVector8std  |2.212853895575859 |
# |40-SpectralEntropystd|2.019895853158216 |
# |62-ChromaVector7std  |1.9830153360262344|
# |64-ChromaVector9std  |1.9106973121503545|
# |67-ChromaVector12std |1.8568609803867127|
# |57-ChromaVector2std  |1.8092411256964591|
# |19-MFCCs11m          |1.66106542578993  |
# |22-ChromaVector1m    |1.5391832159953167|
# |55-MFCCs13std        |1.4435159287711978|
# |10-MFCCs2m           |1.3977133604884837|
# |65-ChromaVector10std |1.3960895034592546|
# |9-MFCCs1m            |1.375444806427007 |
# |43-MFCCs1std         |1.369892930372752 |
# |32-ChromaVector11m   |1.3689337279511207|
# |12-MFCCs4m           |1.336990159860624 |
# |17-MFCCs9m           |1.2527793794702422|
# |49-MFCCs7std         |1.243646101844211 |
# |48-MFCCs6std         |1.22872753690126  |
# |26-ChromaVector5m    |0.9883301470518401|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.63243957296336
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |3-EnergyEntropym      |4.0552149652518885|
# |9-MFCCs1m             |3.9434597135974157|
# |71-BPMessentia        |2.56038471276933  |
# |58-ChromaVector3std   |1.7792535338206903|
# |38-SpectralCentroidstd|1.6132384686401373|
# |60-ChromaVector5std   |1.5861416995310296|
# |67-ChromaVector12std  |1.479734854934567 |
# |41-SpectralFluxstd    |1.4578032330604809|
# |57-ChromaVector2std   |1.2943831768058196|
# |42-SpectralRolloffstd |1.287615561451912 |
# |36-Energystd          |1.1893430906729632|
# |2-Energym             |1.1820838824684248|
# |62-ChromaVector7std   |1.1760785784803507|
# |61-ChromaVector6std   |1.1489881659185988|
# |43-MFCCs1std          |0.9673287409636294|
# |55-MFCCs13std         |0.9096964078368589|
# |64-ChromaVector9std   |0.8811936749239916|
# |40-SpectralEntropystd |0.8158856940212122|
# |23-ChromaVector2m     |0.8132695410088588|
# |17-MFCCs9m            |0.7641971839471204|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.90813013108732
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |56-ChromaVector1std |4.835019300905382 |
# |9-MFCCs1m           |2.8448220959824453|
# |43-MFCCs1std        |2.23378910605381  |
# |50-MFCCs8std        |1.775657599889276 |
# |49-MFCCs7std        |1.698357409153429 |
# |41-SpectralFluxstd  |1.6640938915380439|
# |62-ChromaVector7std |1.383752950485025 |
# |66-ChromaVector11std|1.35469787070291  |
# |58-ChromaVector3std |1.3145079723564774|
# |28-ChromaVector7m   |1.294058425187266 |
# |18-MFCCs10m         |1.269210481756591 |
# |35-ZCRstd           |1.2648964114400143|
# |26-ChromaVector5m   |1.2478279615976227|
# |69-BPM              |1.1775502618225544|
# |65-ChromaVector10std|1.1695858727140573|
# |21-MFCCs13m         |1.0913321043647062|
# |52-MFCCs10std       |1.043749564305881 |
# |13-MFCCs5m          |0.9852022534873321|
# |59-ChromaVector4std |0.9743939313715566|
# |48-MFCCs6std        |0.8654687946575764|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.03279312010567
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |70-BPMconf           |6.7816856692297325|
# |67-ChromaVector12std |2.257752104477983 |
# |63-ChromaVector8std  |2.240855568723606 |
# |2-Energym            |2.018948133258794 |
# |69-BPM               |1.8810783375028048|
# |48-MFCCs6std         |1.5285965285868228|
# |18-MFCCs10m          |1.425722359819046 |
# |71-BPMessentia       |1.3630250120131124|
# |46-MFCCs4std         |1.3618011903758307|
# |3-EnergyEntropym     |1.3206496502072491|
# |9-MFCCs1m            |1.3146550405495574|
# |5-SpectralSpreadm    |1.2285553044151531|
# |28-ChromaVector7m    |1.1271537458830951|
# |52-MFCCs10std        |1.0730099368460448|
# |68-ChromaDeviationstd|1.0289746066222873|
# |14-MFCCs6m           |0.9151071438470648|
# |59-ChromaVector4std  |0.9112853582110336|
# |58-ChromaVector3std  |0.6520060222546871|
# |54-MFCCs12std        |0.5394910476024845|
# |53-MFCCs11std        |0.5220205974332339|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  8.85135047377526
# Top 20 Coefficients:
# +----------------------+-------------------+
# |feature               |coeff              |
# +----------------------+-------------------+
# |2-Energym             |3.8355200470756268 |
# |7-SpectralFluxm       |3.4475973672219045 |
# |13-MFCCs5m            |2.5395641585135262 |
# |70-BPMconf            |2.508690970565982  |
# |1-ZCRm                |2.2320957067677742 |
# |45-MFCCs3std          |1.7007496245581868 |
# |38-SpectralCentroidstd|1.3144666166598282 |
# |15-MFCCs7m            |1.2973960472227501 |
# |28-ChromaVector7m     |1.2654938935179343 |
# |30-ChromaVector9m     |0.8849955282428976 |
# |71-BPMessentia        |0.6982576416197549 |
# |56-ChromaVector1std   |0.601323399394634  |
# |8-SpectralRolloffm    |0.48291074232892056|
# |19-MFCCs11m           |0.4153345660570097 |
# |44-MFCCs2std          |0.40674969123705507|
# |66-ChromaVector11std  |0.3204919496613607 |
# |29-ChromaVector8m     |0.29694557576875524|
# |4-SpectralCentroidm   |0.2960445521496933 |
# |35-ZCRstd             |0.21500275862233936|
# |21-MFCCs13m           |0.10486837124805039|
# +----------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.786345757796234
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |69-BPM             |3.8378717777622193|
# |44-MFCCs2std       |3.757045872660429 |
# |36-Energystd       |3.0134952098059236|
# |54-MFCCs12std      |2.7024127218429252|
# |55-MFCCs13std      |2.616659239914876 |
# |18-MFCCs10m        |2.0667945618237473|
# |3-EnergyEntropym   |2.0625480682885087|
# |27-ChromaVector6m  |1.9627816831549043|
# |34-ChromaDeviationm|1.9623516221828021|
# |49-MFCCs7std       |1.320402914171867 |
# |14-MFCCs6m         |1.1373866682697562|
# |63-ChromaVector8std|1.0719277265302216|
# |46-MFCCs4std       |1.043836995684256 |
# |48-MFCCs6std       |0.9729307746130845|
# |6-SpectralEntropym |0.9217779055571375|
# |2-Energym          |0.8271217464157931|
# |24-ChromaVector3m  |0.770972250930562 |
# |60-ChromaVector5std|0.7247285349112289|
# |53-MFCCs11std      |0.569781000761748 |
# |52-MFCCs10std      |0.5484391048610416|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.570899386984598
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |57-ChromaVector2std   |3.670036769398547 |
# |11-MFCCs3m            |2.791778316569195 |
# |71-BPMessentia        |2.3330198066009493|
# |63-ChromaVector8std   |2.3108436787322972|
# |35-ZCRstd             |2.2273317554091268|
# |43-MFCCs1std          |1.9013446471826594|
# |46-MFCCs4std          |1.8740102785226038|
# |64-ChromaVector9std   |1.656382965684547 |
# |13-MFCCs5m            |1.527835094252582 |
# |54-MFCCs12std         |1.4516203221488402|
# |40-SpectralEntropystd |1.3483421190557385|
# |17-MFCCs9m            |1.1675933349775518|
# |36-Energystd          |1.1565176249687181|
# |38-SpectralCentroidstd|1.154741089311185 |
# |55-MFCCs13std         |1.1144467656348316|
# |53-MFCCs11std         |0.964891040818928 |
# |9-MFCCs1m             |0.837556783691304 |
# |1-ZCRm                |0.7100252118264072|
# |14-MFCCs6m            |0.6431516970048627|
# |44-MFCCs2std          |0.6020908149666657|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.510617052285261
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |37-EnergyEntropystd  |2.956227409277304 |
# |36-Energystd         |2.826200208312268 |
# |60-ChromaVector5std  |2.694718519104451 |
# |39-SpectralSpreadstd |1.9570994032710463|
# |58-ChromaVector3std  |1.901969965561416 |
# |30-ChromaVector9m    |1.8030039787257426|
# |11-MFCCs3m           |1.7217693119761701|
# |63-ChromaVector8std  |1.6938491603713939|
# |9-MFCCs1m            |1.6784379150451159|
# |68-ChromaDeviationstd|1.6711217927408966|
# |49-MFCCs7std         |1.5759445446047573|
# |32-ChromaVector11m   |1.5509871911152289|
# |47-MFCCs5std         |1.4490082950154517|
# |53-MFCCs11std        |1.3430697537896903|
# |18-MFCCs10m          |1.2666778259193379|
# |20-MFCCs12m          |1.2415257126010064|
# |28-ChromaVector7m    |1.1960696584177122|
# |56-ChromaVector1std  |1.0657521492507693|
# |23-ChromaVector2m    |1.0614952375932916|
# |16-MFCCs8m           |1.0362132972114622|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.6084745236583342
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |41-SpectralFluxstd    |4.343366327518438 |
# |7-SpectralFluxm       |2.8787950427442444|
# |43-MFCCs1std          |2.0862085271007293|
# |21-MFCCs13m           |2.0669073987926017|
# |25-ChromaVector4m     |2.0206453317466915|
# |39-SpectralSpreadstd  |2.0160516080463693|
# |47-MFCCs5std          |1.9635461491273531|
# |29-ChromaVector8m     |1.9129962257076174|
# |27-ChromaVector6m     |1.9050744709743999|
# |71-BPMessentia        |1.7898296856924607|
# |20-MFCCs12m           |1.5973316284832801|
# |38-SpectralCentroidstd|1.552654721802351 |
# |13-MFCCs5m            |1.133496590855444 |
# |45-MFCCs3std          |1.0270893601660032|
# |34-ChromaDeviationm   |0.830383270016909 |
# |42-SpectralRolloffstd |0.8248017706886278|
# |28-ChromaVector7m     |0.7937650676334957|
# |33-ChromaVector12m    |0.7841359537081454|
# |10-MFCCs2m            |0.6507950703094229|
# |44-MFCCs2std          |0.6392962839466249|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.6680073517534986
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |12-MFCCs4m            |2.5386979256312303|
# |26-ChromaVector5m     |2.3296057860453487|
# |31-ChromaVector10m    |1.8621964310469798|
# |70-BPMconf            |1.8397304863488204|
# |20-MFCCs12m           |1.8323645133703088|
# |10-MFCCs2m            |1.8257421719894695|
# |32-ChromaVector11m    |1.8090242238180434|
# |27-ChromaVector6m     |1.8012083248326511|
# |65-ChromaVector10std  |1.753905928280272 |
# |64-ChromaVector9std   |1.361694689117882 |
# |41-SpectralFluxstd    |1.343557759778422 |
# |58-ChromaVector3std   |1.3249636356772274|
# |63-ChromaVector8std   |1.238494660005898 |
# |22-ChromaVector1m     |1.223688574504992 |
# |40-SpectralEntropystd |1.2155020666420149|
# |29-ChromaVector8m     |1.1706875670903132|
# |38-SpectralCentroidstd|1.1667789224432492|
# |30-ChromaVector9m     |1.123388572414864 |
# |54-MFCCs12std         |1.1064081922438813|
# |36-Energystd          |1.054765486875    |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.3379241585518609
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |71-BPMessentia       |7.801969357900836 |
# |7-SpectralFluxm      |3.729415713717367 |
# |69-BPM               |3.670508095528292 |
# |62-ChromaVector7std  |3.0071424490222776|
# |9-MFCCs1m            |2.791099071070037 |
# |41-SpectralFluxstd   |2.7600662637401174|
# |29-ChromaVector8m    |2.271423521720549 |
# |67-ChromaVector12std |2.0130392191572715|
# |68-ChromaDeviationstd|1.9784492039801131|
# |57-ChromaVector2std  |1.8485074813191742|
# |66-ChromaVector11std |1.785834709273276 |
# |63-ChromaVector8std  |1.4631384016556586|
# |49-MFCCs7std         |1.4496030672526203|
# |31-ChromaVector10m   |1.2151629569714246|
# |17-MFCCs9m           |1.189671076704244 |
# |12-MFCCs4m           |1.1151389401024716|
# |27-ChromaVector6m    |0.8796477913845637|
# |23-ChromaVector2m    |0.675768390801699 |
# |47-MFCCs5std         |0.5467069244408184|
# |20-MFCCs12m          |0.5308450614523382|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.7950730326364726
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |47-MFCCs5std         |3.447968611408531 |
# |45-MFCCs3std         |3.3711391717860804|
# |59-ChromaVector4std  |2.671041955905929 |
# |68-ChromaDeviationstd|2.3790540771451902|
# |66-ChromaVector11std |2.2259890975595833|
# |55-MFCCs13std        |2.1814210950199757|
# |34-ChromaDeviationm  |2.0135285590722285|
# |51-MFCCs9std         |1.8859431163488838|
# |39-SpectralSpreadstd |1.7903323360905274|
# |15-MFCCs7m           |1.721686446137816 |
# |67-ChromaVector12std |1.5800576892863922|
# |63-ChromaVector8std  |1.5486650439109484|
# |16-MFCCs8m           |1.5147183371231665|
# |25-ChromaVector4m    |1.5056640512507862|
# |20-MFCCs12m          |1.246744553721344 |
# |54-MFCCs12std        |1.1705642632323587|
# |12-MFCCs4m           |1.1408448289575128|
# |69-BPM               |1.1168964583661423|
# |50-MFCCs8std         |1.0547982096995103|
# |27-ChromaVector6m    |1.0517262796001758|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.996247331467003
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |35-ZCRstd             |2.3039650020428315|
# |30-ChromaVector9m     |2.0350822713105323|
# |43-MFCCs1std          |1.9530469418142082|
# |71-BPMessentia        |1.9519008317379298|
# |25-ChromaVector4m     |1.8424110905784292|
# |38-SpectralCentroidstd|1.6075247955050787|
# |11-MFCCs3m            |1.5067053596269966|
# |10-MFCCs2m            |1.5028164789227747|
# |16-MFCCs8m            |1.2871572380382292|
# |56-ChromaVector1std   |1.220737910908506 |
# |44-MFCCs2std          |1.21887114503184  |
# |37-EnergyEntropystd   |1.2176296739043238|
# |60-ChromaVector5std   |1.176853261555603 |
# |41-SpectralFluxstd    |1.1572302937320946|
# |54-MFCCs12std         |1.0721422561834404|
# |47-MFCCs5std          |1.0197403325584369|
# |29-ChromaVector8m     |0.9897931520513589|
# |45-MFCCs3std          |0.9592382628457206|
# |42-SpectralRolloffstd |0.9470196206367332|
# |48-MFCCs6std          |0.8761865539923206|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.77835772748068
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |19-MFCCs11m          |2.521405101483197 |
# |22-ChromaVector1m    |1.85725412396542  |
# |45-MFCCs3std         |1.7664454786124646|
# |55-MFCCs13std        |1.6323325848034476|
# |41-SpectralFluxstd   |1.5394656128714952|
# |18-MFCCs10m          |1.5338230532243495|
# |36-Energystd         |1.4773895948962616|
# |56-ChromaVector1std  |1.3634690757089956|
# |30-ChromaVector9m    |1.2729775904948044|
# |44-MFCCs2std         |1.2685653966044725|
# |42-SpectralRolloffstd|1.2593741871429858|
# |28-ChromaVector7m    |1.242082914990715 |
# |71-BPMessentia       |1.0891667039568074|
# |9-MFCCs1m            |1.002022851634656 |
# |46-MFCCs4std         |0.8965548546109224|
# |60-ChromaVector5std  |0.8721881330220504|
# |70-BPMconf           |0.8379071117209931|
# |65-ChromaVector10std |0.8228898281745346|
# |12-MFCCs4m           |0.8168199522900208|
# |7-SpectralFluxm      |0.7919819470643517|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.2288226906661923
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |66-ChromaVector11std|2.1296252927933708|
# |9-MFCCs1m           |1.9243314213934481|
# |19-MFCCs11m         |1.8667408280315163|
# |5-SpectralSpreadm   |1.8405891031369455|
# |20-MFCCs12m         |1.8371294497370811|
# |23-ChromaVector2m   |1.803683321124247 |
# |62-ChromaVector7std |1.626321716846131 |
# |3-EnergyEntropym    |1.4832220692059301|
# |59-ChromaVector4std |1.4714913253422952|
# |25-ChromaVector4m   |1.4120340429885148|
# |56-ChromaVector1std |1.3964027818268785|
# |30-ChromaVector9m   |1.36858297376119  |
# |27-ChromaVector6m   |1.2741922834203894|
# |21-MFCCs13m         |1.2397346806704785|
# |71-BPMessentia      |1.169184294063051 |
# |33-ChromaVector12m  |1.1457638727764394|
# |41-SpectralFluxstd  |0.9690007104215765|
# |31-ChromaVector10m  |0.9570879214427416|
# |4-SpectralCentroidm |0.9123827440529767|
# |60-ChromaVector5std |0.8230880883239909|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# +----------+------+
# |Classifier|Result|
# +----------+------+
# |OneVsRest |48.63 |
# +----------+------+

# %% [markdown]
# ## Make a recommendation to a user!
#
# Imagine that your new model is being deployed in the next version release of the online radio station that has now purchased this model from you. So the existing users have gotten used to the songs in certian stations but now your model may be adding new songs to those stations.

# %%
predictions = OVR_BestModel.transform(test)

# %%
# From the output earlier we saw that the new label for BigRoom is now 21.0
# Let's get a song from there
count = predictions.filter("label!=21.0 AND prediction == 21.0").count()
print(count)
predictions.filter("label!=21.0 AND prediction == 21.0").show()
# predictions.show()
# Out:
# 6
# +-----+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|prediction|
# +-----+--------------------+--------------------+----------+
# |  7.0|[0.25472467994853...|[-6.1408517463132...|      21.0|
# | 16.0|[0.19132401663329...|[-4.5537586686746...|      21.0|
# | 17.0|[0.04522334547245...|[-5.1187385126796...|      21.0|
# | 17.0|[0.21506751276683...|[-6.0697399258657...|      21.0|
# | 17.0|[0.26078806292584...|[-4.9216260095715...|      21.0|
# | 20.0|[0.34565765181533...|[-5.7681660361027...|      21.0|
# +-----+--------------------+--------------------+----------+
